# %% [markdown]
# <a href="https://colab.research.google.com/github/ssoma2mc/Data110/blob/main/ShinkoSoma_Project1_Task1%262_Selection%26EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question:
#
# - Data Dictionary: I can not find the data dictionary. (I have checked kaggle but its life expectancy data set is different from ours.)
# - Is it necessary to rename variables into the names without space?
# - When 'df.dropna' should be applied? I had trouble when I try pair plot'. The function does not work if data set contain Nan. If I include corrupition', the number of data was reduced significantly becasue it contains too many Nan.
# - I continued to check each variable. Which dataframe should I use for this task: df or df_2019? Generally, I understand that df is appropriate, so I proceeded with it. However, in areas with sparse data, I noticed that the data is connected, and upon closer inspection, it turns out to be continuous data for a single country. Would this still be fine for analysis or modeling?
# - I wrote linear regression lines, but I think that I should have chosen different ones.
# - Especially, for the analysis of CO2 and life expectancy, I can't evaluate entire data and create three separate graphs. Are there any better way?
# - I don't fully understand modeling, train data and test data, but I tried follwoing manuals. Is it wrong?

# %% [markdown]
# # Data 110 Data Visualization
# # Project 1:

# %% [markdown]
# # **Task 1. Dataset Selection**
#
#
# - I chose the dataset 'life_exp_kaggle_full.csv'.
#
# - The data is assumed to be sourced from Kaggle's life expectancy dataset from the WHO. However, it differs from the Kaggle dataset available on their website, and I could not find a data dictionary to verify the dataset's specifics.
#
# - Breafly mentioning about life expectancy,  life expectancy refers to the average number of years a person born in a specific country or region can expect to live in good health, as opposed to being a simple statistic of the age at death.
#
# - Factors that influence life expectancy, according to existing literature, include variables such as income, education, healthcare, and nutrition 1-3).
#
# - All of the data in this dataset are considered predictor variables, as they are well-known determinants of life expectancy. While region and race can also be predictors, they are generally secondary factors.
#
# - Recently, the impact of CO2 on life expectancy has attracted significant attention 4).
#
#       1) Mackenbach, J. P., Valverde, J. R., Bopp, M., Brønnum-Hansen, H., Deboosere, P., Kalediene, R., Kovács, K., Leinsalu, M., Martikainen, P., Menvielle, G., Regidor, E., & Nusselder, W. J. (2019). Determinants of inequalities in life expectancy: an international comparative study of eight risk factors. The Lancet. Public Health, 4(10), e529–e537. https://doi.org/10.1016/S2468-2667(19)30147-1
#       2) Hauck, K., Martin, S., & Smith, P. C. (2016). Priorities for action on the social determinants of health: Empirical evidence on the strongest associations with life expectancy in 54 low-income countries, 1990–2012. Social Science & Medicine (1982), 167, 88–98. https://doi.org/10.1016/j.socscimed.2016.08.035
#       3) Eriksen, S., & Wiese, R. (2019). Policy induced increases in private healthcare financing provide short-term relief of total healthcare expenditure growth: Evidence from OECD countries. European Journal of Political Economy, 59, 71–82. https://doi.org/10.1016/j.ejpoleco.2019.02.001
#       4) Bressler, R. D. (2021). The mortality cost of carbon. Nature Communications, 12(1), 1–12. https://doi.org/10.1038/s41467-021-24487-w

# %% [markdown]
# # **Task 2: Exploratory Data Analysis (EDA)**
#
# 2.1. Firtst, I used the following codes and explor the data.
#       - df.head()
#       - df.tail()
#       - df.shape
#       - df.info()
#       - df.describe()
#       - df.isna().sum()
#
#       - sns.heatmap(df.isna(), cmap='coolwarm', cbar=False)
#       - plt.show()
#
#       - df.duplicated().sum()
#       - df.nunique()
#       - df.corr()
#
#       - for numerical data
#         - numeric_df = df.select_dtypes(include=['number'])
#         - numeric_df.corr()
#
#         - plt.figure(figsize=(10, 8))
#         - sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
#         - plt.title("Correlation Matrix")
#         - plt.show()
#
#       - for categorical data
#         - categorical_df = df.select_dtypes(include=['object'])
#         - print(categorical_df.head())
#         - df[''].value_counts()
#         - df[''].value_counts(normalize=True) * 100
# 2.2. After that, I use the data to answer the following basic qustions.
#
#     - 1) What is the current Life Expectancy? →  This is written in Task 3 Data Visualization.
#     - 2) How does Life Expectancy vary by country, and reagion? →  This is written in Task 3 Data Visualization.
#     - 3) What factors influence Life Expectancy? →  This is written in Task 3 Data Visualization.
#     - 4) Can we predict the life expectacy from this data?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats
from scipy.optimize import curve_fit

# %%
sns.set_style("whitegrid")
sns.color_palette("viridis", n_colors=10)
# Out:
# [(0.283072, 0.130895, 0.449241),
#  (0.262138, 0.242286, 0.520837),
#  (0.220057, 0.343307, 0.549413),
#  (0.177423, 0.437527, 0.557565),
#  (0.143343, 0.522773, 0.556295),
#  (0.119512, 0.607464, 0.540218),
#  (0.166383, 0.690856, 0.496502),
#  (0.319809, 0.770914, 0.411152),
#  (0.525776, 0.833491, 0.288127),
#  (0.762373, 0.876424, 0.137064)]

# %%
colors = sns.color_palette("viridis", n_colors=10)

# %%
file_path = 'https://raw.githubusercontent.com/ssoma2mc/Data110/main/Project_1/life_exp_kaggle_full.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ### Task 2.1.1 Data Data Exploration

# %%
#df.head()
#df.tail()
#df.shape
#df.info()
#df.describe()
#df.isna().sum()
#sns.heatmap(df.isna(), cmap='coolwarm', cbar=False)
#plt.show()
#df.duplicated().sum()
#df.nunique()
#df.corr()

## for numerical data
#numeric_df = df.select_dtypes(include=['number'])
#numeric_df.corr()

#plt.figure(figsize=(10, 8))
#sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
#plt.title("Correlation Matrix")
#plt.show()

## for categorical data
#categorical_df = df.select_dtypes(include=['object'])
##print(categorical_df.head())
#df[''].value_counts()
#df[''].value_counts(normalize=True) * 100

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3306 entries, 0 to 3305
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country Name                    3306 non-null   object
#  1   Country Code                    3306 non-null   object
#  2   Region                          3306 non-null   object
#  3   IncomeGroup                     3306 non-null   object
#  4   Year                            3306 non-null   int64
#  5   Life Expectancy World Bank      3118 non-null   float64
#  6   Prevelance of Undernourishment  2622 non-null   float64
#  7   CO2                             3154 non-null   float64
#  8   Health Expenditure %            3126 non-null   float64
#  9   Education Expenditure %         2216 non-null   float64
#  10  Unemployment                    3002 non-null   float64
#  11  Corruption                      975 non-null    float64
# ...

# %%
df.head()
# Out:
#            Country Name Country Code                      Region  \
# 0           Afghanistan          AFG                  South Asia
# 1                Angola          AGO          Sub-Saharan Africa
# 2               Albania          ALB       Europe & Central Asia
# 3               Andorra          AND       Europe & Central Asia
# 4  United Arab Emirates          ARE  Middle East & North Africa
#
#            IncomeGroup  Year  Life Expectancy World Bank  \
# 0           Low income  2001                      56.308
# 1  Lower middle income  2001                      47.059
# 2  Upper middle income  2001                      74.288
# 3          High income  2001                         NaN
# 4          High income  2001                      74.544
#
#    Prevelance of Undernourishment      CO2  Health Expenditure %  \
# 0                            47.8    730.0                   NaN
# 1                            67.5  15960.0              4.483516
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Region', 'IncomeGroup', 'Year',
#        'Life Expectancy World Bank', 'Prevelance of Undernourishment', 'CO2',
#        'Health Expenditure %', 'Education Expenditure %', 'Unemployment',
#        'Corruption', 'Sanitation', 'Injuries', 'Communicable',
#        'NonCommunicable'],
#       dtype='object')

# %%
# Rename: without space?
df.rename({'Country Name' : 'country',
           'Country Code' : 'country_code',
           'Region' : 'region',
           'IncomeGroup' : 'income',
           'Year' : 'year',
           'Life Expectancy World Bank' : 'life_expectancy',
           'Prevelance of Undernourishment' : 'under_nourishment',
           'CO2': 'co2',
           'Health Expenditure %' : 'health_expenditure',
           'Education Expenditure %' : 'education_expenditure',
           'Unemployment' : 'unemployment',
           'Corruption' : 'corruption' ,
           'Sanitation' : 'sanitation',
           'Injuries' : 'injuries',
           'Communicable' : 'communicable' ,
           'NonCommunicable': 'non_communicable' ,
           },axis=1,inplace=True)

# %%
df.head()
# Out:
#                 country country_code                      region  \
# 0           Afghanistan          AFG                  South Asia
# 1                Angola          AGO          Sub-Saharan Africa
# 2               Albania          ALB       Europe & Central Asia
# 3               Andorra          AND       Europe & Central Asia
# 4  United Arab Emirates          ARE  Middle East & North Africa
#
#                 income  year  life_expectancy  under_nourishment      co2  \
# 0           Low income  2001           56.308               47.8    730.0
# 1  Lower middle income  2001           47.059               67.5  15960.0
# 2  Upper middle income  2001           74.288                4.9   3230.0
# 3          High income  2001              NaN                NaN    520.0
# 4          High income  2001           74.544                2.8  97200.0
#
#    health_expenditure  education_expenditure  unemployment  corruption  \
# ...

# %%
df.tail()
# Out:
#            country country_code               region               income  \
# 3301       Vanuatu          VUT  East Asia & Pacific  Lower middle income
# 3302         Samoa          WSM  East Asia & Pacific  Lower middle income
# 3303  South Africa          ZAF   Sub-Saharan Africa  Upper middle income
# 3304        Zambia          ZMB   Sub-Saharan Africa           Low income
# 3305      Zimbabwe          ZWE   Sub-Saharan Africa  Lower middle income
#
#       year  life_expectancy  under_nourishment            co2  \
# 3301  2019           70.474               12.4     209.999993
# 3302  2019           73.321                4.4     300.000012
# 3303  2019           64.131                6.3  439640.014600
# 3304  2019           63.886                NaN    6800.000191
# 3305  2019           61.490                NaN   11760.000230
#
#       health_expenditure  education_expenditure  unemployment  corruption  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3306 entries, 0 to 3305
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                3306 non-null   object
#  1   country_code           3306 non-null   object
#  2   region                 3306 non-null   object
#  3   income                 3306 non-null   object
#  4   year                   3306 non-null   int64
#  5   life_expectancy        3118 non-null   float64
#  6   under_nourishment      2622 non-null   float64
#  7   co2                    3154 non-null   float64
#  8   health_expenditure     3126 non-null   float64
#  9   education_expenditure  2216 non-null   float64
#  10  unemployment           3002 non-null   float64
#  11  corruption             975 non-null    float64
#  12  sanitation             2059 non-null   float64
#  13  injuries               3306 non-null   float64
# ...

# %%
df.describe()
# Out:
#               year  life_expectancy  under_nourishment           co2  \
# count  3306.000000      3118.000000        2622.000000  3.154000e+03
# mean   2010.000000        69.748362          10.663654  1.574924e+05
# std       5.478054         9.408154          11.285897  7.726415e+05
# min    2001.000000        40.369000           2.500000  1.000000e+01
# 25%    2005.000000        63.642000           2.500000  2.002500e+03
# 50%    2010.000000        72.168500           6.200000  1.020500e+04
# 75%    2015.000000        76.809000          14.775000  5.877250e+04
# max    2019.000000        84.356341          70.900000  1.070722e+07
#
#        health_expenditure  education_expenditure  unemployment  corruption  \
# count         3126.000000            2216.000000   3002.000000  975.000000
# mean             6.364059               4.589014      7.890760    2.860513
# std              2.842844               2.119165      6.270832    0.621343
# ...

# %%
df.isna().sum()
# Out:
# country                     0
# country_code                0
# region                      0
# income                      0
# year                        0
# life_expectancy           188
# under_nourishment         684
# co2                       152
# health_expenditure        180
# education_expenditure    1090
# unemployment              304
# corruption               2331
# sanitation               1247
# injuries                    0
# communicable                0
# non_communicable            0
# dtype: int64

# %%
sns.heatmap(df.isna(), cmap='Blues', cbar=False)
plt.title('Missing Data Heatmap')
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# country                   174
# country_code              174
# region                      7
# income                      4
# year                       19
# life_expectancy          2964
# under_nourishment         399
# co2                      2259
# health_expenditure       3126
# education_expenditure    2192
# unemployment             2151
# corruption                  8
# sanitation               1941
# injuries                 3306
# communicable             3306
# non_communicable         3306
# dtype: int64

# %%
# for numerical data
numeric_df = df.select_dtypes(include=['number'])
#print(numeric_df.head())
print(numeric_df.corr())
# Out:
#                            year  life_expectancy  under_nourishment       co2  \
# year                   1.000000         0.203013          -0.144081  0.023258
# life_expectancy        0.203013         1.000000          -0.686749  0.130382
# under_nourishment     -0.144081        -0.686749           1.000000 -0.117334
# co2                    0.023258         0.130382          -0.117334  1.000000
# health_expenditure     0.093686         0.326404          -0.259551  0.109116
# education_expenditure  0.029346         0.208019          -0.248436 -0.042915
# unemployment          -0.050321        -0.056668          -0.037870 -0.058695
# corruption            -0.013471         0.263566          -0.307317  0.072381
# sanitation             0.117233         0.680025          -0.547040  0.097204
# injuries              -0.005951        -0.006020           0.012722  0.649054
# communicable          -0.037286        -0.217812           0.140288  0.206830
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
# for categorical data
categorical_df = df.select_dtypes(include=['object'])
#print(categorical_df.head())

df['region'].value_counts()
df['region'].value_counts(normalize=True) * 100

#df['IncomeGroup'].value_counts()
#df['IncomeGroup'].value_counts(normalize=True) * 100
# Out:
# region
# Europe & Central Asia         27.011494
# Sub-Saharan Africa            25.287356
# Latin America & Caribbean     16.666667
# East Asia & Pacific           15.517241
# Middle East & North Africa     9.195402
# South Asia                     4.597701
# North America                  1.724138
# Name: proportion, dtype: float64

# %%
df['income'].value_counts()
df['income'].value_counts(normalize=True) * 100
# Out:
# income
# High income            32.758621
# Upper middle income    28.160920
# Lower middle income    25.862069
# Low income             13.218391
# Name: proportion, dtype: float64

# %% [markdown]
# ## Task 2.2 1) What is the current Life Expectancy?
#
# → This is written in Task 3 Data Visualization.

# %%
# 1) What is the current Life Expectancy?
stats_2019 = df[df['year'] == 2019]['life_expectancy']
print(stats_2019.describe())
# Out:
# count    164.000000
# mean      72.589112
# std        7.706562
# min       53.283000
# 25%       67.094250
# 50%       74.231341
# 75%       78.444793
# max       84.356341
# Name: life_expectancy, dtype: float64

# %% [markdown]
# ## Task 2.2 3) How does Life Expectancy vary by country, and reagion?
#
# →  This is written in Task 3 Data Visualization.

# %%
df_grouped = df_2019.groupby('region')['life_expectancy'].mean().reset_index()
print(df_grouped)
# Out:
#                        region  life_expectancy
# 0         East Asia & Pacific        74.096990
# 1       Europe & Central Asia        78.212050
# 2   Latin America & Caribbean        75.295054
# 3  Middle East & North Africa        76.498838
# 4               North America        80.901057
# 5                  South Asia        71.600875
# 6          Sub-Saharan Africa        62.715777

# %% [markdown]
# ## Task 1.2 3) What factors influence Life Expectancy?
#
# → This is written in Task 3 Data Visualization.

# %% [markdown]
# ### Task 1.2 4) Can we predict the life expectacy from this data?

# %% [markdown]
# The stepwise method is not recommended due to the potential for overfitting. In this case, the correlation was assessed using the correlation matrix, and features with high correlations (above 0.8) were excluded.
#
# Feature selection should be based on prior literature.
#
# The variables in this dataset are expected to have strong relationships with life expectancy, as indicated by the literature review (referenced sources).
#
# However, some of the variables exhibit high correlations with one another. Including highly correlated variables in the same model can lead to multicollinearity, which may decrease the accuracy and interpretability of the prediction model. Generally, if the correlation coefficient between variables exceeds 0.7, it is recommended to avoid including these variables together in the model. In this dataset, the correlation between injuries and non_communicable is 0.95, between injuries and communicable is 0.77, between CO2 and non_communicable is 0.82, and between sanitation and life_expectancy is 0.68. Therefore, injuries, CO2, and sanitation were excluded from the model.
#
# Since, I am not familier with other models, my only choice was a linear regression.
#
# I checked Lineality, Normal Distribution of Residuals, Breusch-Pagan Test, and
# VIF as as assumptions for applying a linear regression model
#
# I checked R² (Coefficient of Determination), Training Mean Squared Error, and
# Testing Mean Squared Error as evaluation of models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor
import joblib


from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.metrics import r2_score

# %%
# **Model 1: Base Model**
file_path = 'https://raw.githubusercontent.com/ssoma2mc/Data110/main/Project_1/life_exp_kaggle_full.csv'
df = pd.read_csv(file_path)

df.rename({'Country Name': 'country',
           'Country Code': 'country_code',
           'Region': 'region',
           'IncomeGroup': 'income',
           'Year': 'year',
           'Life Expectancy World Bank': 'life_expectancy',
           'Prevelance of Undernourishment': 'under_nourishment',
           'CO2': 'co2',
           'Health Expenditure %': 'health_expenditure',
           'Education Expenditure %': 'education_expenditure',
           'Unemployment': 'unemployment',
           'Corruption': 'corruption',
           'Sanitation': 'sanitation',
           'Injuries': 'injuries',
           'Communicable': 'communicable',
           'NonCommunicable': 'non_communicable'}, axis=1, inplace=True)

# Data Cleaning
df_cleaned = df.dropna(subset=['under_nourishment', 'health_expenditure', 'education_expenditure',
                'unemployment', 'communicable', 'non_communicable', 'income', 'corruption']).copy()

# Encode categorical variable: 'income'
income_group_mapping = {'Low income': 1, 'Lower middle income': 2, 'Upper middle income': 3, 'High income': 4}
df_cleaned['income_group_encoded'] = df_cleaned['income'].map(income_group_mapping)

# Define features and target variable
X_1 = df_cleaned[['under_nourishment', 'health_expenditure', 'education_expenditure',
                'unemployment', 'communicable', 'non_communicable', 'income_group_encoded', 'corruption']]
y_1 = df_cleaned['life_expectancy']

# Split into training and test datasets
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X_1, y_1, test_size=0.2, random_state=42)

# Standardize features
scaler_1 = StandardScaler()
X_train_scaled_1 = scaler_1.fit_transform(X_train_1)
X_test_scaled_1 = scaler_1.transform(X_test_1)

# Initialize and train the linear regression model
linear_model_1 = LinearRegression()
linear_model_1.fit(X_train_scaled_1, y_train_1)

# Get and print coefficients
coefficients_1 = pd.DataFrame(linear_model_1.coef_, X_1.columns, columns=["Coefficient"])
print(coefficients_1)

# Make predictions
y_pred_1 = linear_model_1.predict(X_test_scaled_1)

# Evaluate model
mse_1 = mean_squared_error(y_test_1, y_pred_1)
print(f"Mean Squared Error (Linear Regression) - Model 1: {mse_1}")

# Save the model and the standardization scaler
joblib.dump(linear_model_1, 'linear_model_1.pkl')
joblib.dump(scaler_1, 'scaler_1.pkl')
# Out:
#                        Coefficient
# under_nourishment        -1.487064
# health_expenditure        0.694099
# education_expenditure     0.399529
# unemployment             -2.283867
# communicable             -7.846510
# non_communicable          7.999540
# income_group_encoded      3.270179
# corruption                0.146147
# Mean Squared Error (Linear Regression) - Model 1: 33.707820395607385
# ['scaler_1.pkl']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor

# 1. Normal Distribution of Residuals
residuals_2 = y_test_2 - y_pred_2  # Use Model 2's y_test and y_pred
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
# Residual Plot
sns.scatterplot(x=y_pred_2, y=residuals_2, ax=axes[0])
axes[0].axhline(0, color='r', linestyle='--')
axes[0].set_xlabel('Predicted Values')
axes[0].set_ylabel('Residuals')
axes[0].set_title('Residuals vs Predicted Values')
# Histogram of residuals
sns.histplot(residuals_2, kde=True, ax=axes[1])
axes[1].set_title('Histogram of Residuals')
# Q-Q Plot
stats.probplot(residuals_2, dist="norm", plot=axes[2])
axes[2].set_title('Q-Q Plot of Residuals')
# Adjust layout
plt.tight_layout()
plt.show()

# 3. Check for Heteroscedasticity
X_train_with_const_2 = sm.add_constant(X_train_scaled_2)  # Use Model 2's scaled training data
linear_model_2_sm = sm.OLS(y_train_2, X_train_with_const_2).fit()  # Use Model 2's y_train
bp_test_2 = sms.het_breuschpagan(linear_model_2_sm.resid, linear_model_2_sm.model.exog)
bp_test_stat_2, bp_test_p_value_2, _, _ = bp_test_2
print(f"Breusch-Pagan Test Statistics: {bp_test_stat_2}")
print(f"Breusch-Pagan Test p-value: {bp_test_p_value_2}")

# 4. Check for Multicollinearity
X_with_const_2 = sm.add_constant(X_train_scaled_2)  # Use Model 2's scaled training data
vif_data_2 = pd.DataFrame()
vif_data_2["Variable"] = ['const'] + list(X_2.columns)  # Use Model 2's feature columns
vif_data_2["VIF"] = [variance_inflation_factor(X_with_const_2, i) for i in range(X_with_const_2.shape[1])]
print(vif_data_2)
# Out:
# Breusch-Pagan Test Statistics: 36.9155534264495
# Breusch-Pagan Test p-value: 1.1927858942903553e-05
#                 Variable       VIF
# 0                  const  1.000000
# 1      under_nourishment  1.643657
# 2     health_expenditure  1.332485
# 3  education_expenditure  1.197399
# 4           unemployment  1.337833
# 5           communicable  7.052822
# 6                    co2  6.867689
# 7   income_group_encoded  1.764914
# 8             corruption  1.222506

# %%
from sklearn.metrics import r2_score
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# 1. R²
r2_1 = r2_score(y_test_1, y_pred_1)
print(f"R²: {r2_1}")

# 3. Mean Squared Error (MSE)
X_train_with_const_1 = sm.add_constant(X_train_scaled_1)
linear_model_1_sm = sm.OLS(y_train_1, X_train_with_const_1).fit()

# Predict on train and test sets
X_test_with_const_1 = sm.add_constant(X_test_scaled_1)
y_train_pred_1 = linear_model_1_sm.predict(X_train_with_const_1)
y_test_pred_1 = linear_model_1_sm.predict(X_test_with_const_1)

# Calculate MSE
train_mse_1 = mean_squared_error(y_train_1, y_train_pred_1)
test_mse_1 = mean_squared_error(y_test_1, y_test_pred_1)

print(f"Training Mean Squared Error: {train_mse_1}")
print(f"Testing Mean Squared Error: {test_mse_1}")
# Out:
# R²: 0.42341148759473535
# Training Mean Squared Error: 29.832824069372645
# Testing Mean Squared Error: 33.70782039560738

# %%
# **Model 2: Exclude non_communicable, Add co2**

df_cleaned = df.dropna(subset=['under_nourishment', 'health_expenditure', 'education_expenditure',
                'unemployment', 'communicable', 'co2', 'income', 'corruption']).copy()

# Encode categorical variable: 'income'
income_group_mapping = {'Low income': 1, 'Lower middle income': 2, 'Upper middle income': 3, 'High income': 4}
df_cleaned['income_group_encoded'] = df_cleaned['income'].map(income_group_mapping)

# Define features and target variable
X_2 = df_cleaned[['under_nourishment', 'health_expenditure', 'education_expenditure',
                'unemployment', 'communicable', 'co2', 'income_group_encoded', 'corruption']]
y_2 = df_cleaned['life_expectancy']

# Split into training and test datasets
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_2, y_2, test_size=0.2, random_state=42)

# Standardize features
scaler_2 = StandardScaler()
X_train_scaled_2 = scaler_2.fit_transform(X_train_2)
X_test_scaled_2 = scaler_2.transform(X_test_2)

# Initialize and train the linear regression model
linear_model_2 = LinearRegression()
linear_model_2.fit(X_train_scaled_2, y_train_2)

# Get and print coefficients
coefficients_2 = pd.DataFrame(linear_model_2.coef_, X_2.columns, columns=["Coefficient"])
print(coefficients_2)

# Make predictions
y_pred_2 = linear_model_2.predict(X_test_scaled_2)

# Model evaluation
mse_2 = mean_squared_error(y_test_2, y_pred_2)
print(f"Mean Squared Error (Linear Regression) - Model 2: {mse_2}")

# Save the model and the standardization scaler
joblib.dump(linear_model_2, 'linear_model_2.pkl')
joblib.dump(scaler_2, 'scaler_2.pkl')
# Out:
#                        Coefficient
# under_nourishment        -1.620814
# health_expenditure        0.816422
# education_expenditure     0.245454
# unemployment             -2.262480
# communicable             -3.321611
# co2                       3.499018
# income_group_encoded      3.452324
# corruption                0.136987
# Mean Squared Error (Linear Regression) - Model 2: 36.34038584208771
# ['scaler_2.pkl']

# %%
# Normal Distribution of Residuals
residuals_2 = y_test_2 - y_pred_2
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Residual Plot
sns.scatterplot(x=y_pred_2, y=residuals_2, ax=axes[0])
axes[0].axhline(0, color='r', linestyle='--')
axes[0].set_xlabel('Predicted Values')
axes[0].set_ylabel('Residuals')
axes[0].set_title('Residuals vs Predicted Values')

# Histogram of residuals
sns.histplot(residuals_2, kde=True, ax=axes[1])
axes[1].set_title('Histogram of Residuals')

# Q-Q Plot
stats.probplot(residuals_2, dist="norm", plot=axes[2])
axes[2].set_title('Q-Q Plot of Residuals')

# Adjust layout
plt.tight_layout()
plt.show()

# Check for Heteroscedasticity
X_train_with_const_2 = sm.add_constant(X_train_scaled_2)
linear_model_2_sm = sm.OLS(y_train_2, X_train_with_const_2).fit()

# Breusch-Pagan Test
bp_test_2 = sms.het_breuschpagan(linear_model_2_sm.resid, linear_model_2_sm.model.exog)
bp_test_stat_2, bp_test_p_value_2, _, _ = bp_test_2

print(f"Breusch-Pagan Test Statistics: {bp_test_stat_2}")
print(f"Breusch-Pagan Test p-value: {bp_test_p_value_2}")

# Check for Multicollinearity
X_with_const_2 = sm.add_constant(X_train_scaled_2)
vif_data_2 = pd.DataFrame()
vif_data_2["Variable"] = ['const'] + list(X_2.columns)  # Add 'const'
vif_data_2["VIF"] = [variance_inflation_factor(X_with_const_2, i) for i in range(X_with_const_2.shape[1])]

# Display VIF values
print(vif_data_2)
# Out:
# Breusch-Pagan Test Statistics: 36.9155534264495
# Breusch-Pagan Test p-value: 1.1927858942903553e-05
#                 Variable       VIF
# 0                  const  1.000000
# 1      under_nourishment  1.643657
# 2     health_expenditure  1.332485
# 3  education_expenditure  1.197399
# 4           unemployment  1.337833
# 5           communicable  7.052822
# 6                    co2  6.867689
# 7   income_group_encoded  1.764914
# 8             corruption  1.222506

# %%
from sklearn.metrics import r2_score
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# 1. R²
r2_2 = r2_score(y_test_2, y_pred_2)
print(f"R²: {r2_2}")

# 3. Mean Squared Error (MSE)
X_train_with_const_2 = sm.add_constant(X_train_scaled_2)
linear_model_2_sm = sm.OLS(y_train_2, X_train_with_const_2).fit()

# Predict on train and test sets
X_test_with_const_2 = sm.add_constant(X_test_scaled_2)
y_train_pred_2 = linear_model_2_sm.predict(X_train_with_const_2)
y_test_pred_2 = linear_model_2_sm.predict(X_test_with_const_2)

# Calculate MSE
train_mse_2 = mean_squared_error(y_train_2, y_train_pred_2)
test_mse_2 = mean_squared_error(y_test_2, y_test_pred_2)

print(f"Training Mean Squared Error: {train_mse_2}")
print(f"Testing Mean Squared Error: {test_mse_2}")
# Out:
# R²: 0.37838018694162634
# Training Mean Squared Error: 32.139282609081526
# Testing Mean Squared Error: 36.34038584208773

# %%
# **Model 3: Exclude co2**

df_cleaned = df.dropna(subset=['under_nourishment', 'health_expenditure', 'education_expenditure',
                'unemployment', 'communicable', 'income', 'corruption']).copy()

# Encode categorical variable: 'income'
income_group_mapping = {'Low income': 1, 'Lower middle income': 2, 'Upper middle income': 3, 'High income': 4}
df_cleaned['income_group_encoded'] = df_cleaned['income'].map(income_group_mapping)

# Define features and target variable
X_3 = df_cleaned[['under_nourishment', 'health_expenditure', 'education_expenditure',
                'unemployment', 'communicable', 'income_group_encoded', 'corruption']]
y_3 = df_cleaned['life_expectancy']

# Split into training and test datasets
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(X_3, y_3, test_size=0.2, random_state=42)

# Standardize features
scaler_3 = StandardScaler()
X_train_scaled_3 = scaler_3.fit_transform(X_train_3)
X_test_scaled_3 = scaler_3.transform(X_test_3)

# Initialize and train the linear regression model
linear_model_3 = LinearRegression()
linear_model_3.fit(X_train_scaled_3, y_train_3)

# Get and print coefficients
coefficients_3 = pd.DataFrame(linear_model_3.coef_, X_3.columns, columns=["Coefficient"])
print(coefficients_3)

# Make predictions
y_pred_3 = linear_model_3.predict(X_test_scaled_3)

# Model evaluation
mse_3 = mean_squared_error(y_test_3, y_pred_3)
print(f"Mean Squared Error (Linear Regression) - Model 3: {mse_3}")

# Save the model and the standardization scaler
joblib.dump(linear_model_3, 'linear_model_3.pkl')
joblib.dump(scaler_3, 'scaler_3.pkl')
# Out:
#                        Coefficient
# under_nourishment        -1.786359
# health_expenditure        1.027769
# education_expenditure     0.309299
# unemployment             -2.199720
# communicable             -0.054483
# income_group_encoded      3.695066
# corruption                0.165733
# Mean Squared Error (Linear Regression) - Model 3: 37.05059253291656
# ['scaler_3.pkl']

# %% [markdown]
# | Feature                 | Coefficient |
# |-------------------------|-------------|
# | under_nourishment        | -1.786359   |
# | health_expenditure       | 1.027769    |
# | education_expenditure    | 0.309299    |
# | unemployment             | -2.199720   |
# | communicable             | -0.054483   |
# | income_group_encoded     | 3.695066    |
# | corruption               | 0.165733    |

# %%
#linear_model_3 = joblib.load('linear_model_3.pkl')
#scaler_3 = joblib.load('scaler_3.pkl')

# %%
# Normal Distribution of Residuals
residuals_3 = y_test_3 - y_pred_3
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Residual Plot
sns.scatterplot(x=y_pred_3, y=residuals_3, ax=axes[0])
axes[0].axhline(0, color='r', linestyle='--')
axes[0].set_xlabel('Predicted Values')
axes[0].set_ylabel('Residuals')
axes[0].set_title('Residuals vs Predicted Values')

# Histogram of residuals
sns.histplot(residuals_3, kde=True, ax=axes[1])
axes[1].set_title('Histogram of Residuals')

# Q-Q Plot
stats.probplot(residuals_3, dist="norm", plot=axes[2])
axes[2].set_title('Q-Q Plot of Residuals')

# Adjust layout
plt.tight_layout()
plt.show()

# Check for Heteroscedasticity
X_train_with_const_3 = sm.add_constant(X_train_scaled_3)
linear_model_3_sm = sm.OLS(y_train_3, X_train_with_const_3).fit()

# Breusch-Pagan Test
bp_test_3 = sms.het_breuschpagan(linear_model_3_sm.resid, linear_model_3_sm.model.exog)
bp_test_stat_3, bp_test_p_value_3, _, _ = bp_test_3

print(f"Breusch-Pagan Test Statistics: {bp_test_stat_3}")
print(f"Breusch-Pagan Test p-value: {bp_test_p_value_3}")

# Check for Multicollinearity
X_with_const_3 = sm.add_constant(X_train_scaled_3)
vif_data_3 = pd.DataFrame()
vif_data_3["Variable"] = ['const'] + list(X_3.columns)  # Add 'const'
vif_data_3["VIF"] = [variance_inflation_factor(X_with_const_3, i) for i in range(X_with_const_3.shape[1])]

# Display VIF values
print(vif_data_3)
# Out:
# Breusch-Pagan Test Statistics: 28.552953946736462
# Breusch-Pagan Test p-value: 0.00017451589279852972
#                 Variable       VIF
# 0                  const  1.000000
# 1      under_nourishment  1.628284
# 2     health_expenditure  1.307429
# 3  education_expenditure  1.195112
# 4           unemployment  1.335624
# 5           communicable  1.065253
# 6   income_group_encoded  1.731861
# 7             corruption  1.222042

# %%
# Evaluate the model
from sklearn.metrics import r2_score
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# 1. R²
r2_3 = r2_score(y_test_3, y_pred_3)
print(f"R²: {r2_3}")

# 3. Mean Squared Error(MSE)
X_train_with_const_3 = sm.add_constant(X_train_scaled_3)
linear_model_3_sm = sm.OLS(y_train_3, X_train_with_const_3).fit()
y_train_pred_3 = linear_model_3_sm.predict(X_train_with_const_3)
X_test_with_const_3 = sm.add_constant(X_test_scaled_3)
y_test_pred_3 = linear_model_3_sm.predict(X_test_with_const_3)

train_mse_3 = mean_squared_error(y_train_3, y_train_pred_3)
test_mse_3 = mean_squared_error(y_test_3, y_test_pred_3)

print(f"Training Mean Squared Error: {train_mse_3}")
print(f"Testing Mean Squared Error: {test_mse_3}")
# Out:
# R²: 0.3662317592308084
# Training Mean Squared Error: 33.92199655404379
# Testing Mean Squared Error: 37.05059253291657

# %%
# **Model 4: include co2, exclude communicable, non_communicable**

df_cleaned = df.dropna(subset=['under_nourishment', 'health_expenditure', 'education_expenditure',
                'unemployment', 'co2', 'income', 'corruption']).copy()

# Processing categorical variable 'income'
income_group_mapping = {'Low income': 1, 'Lower middle income': 2, 'Upper middle income': 3, 'High income': 4}
df_cleaned['income_group_encoded'] = df_cleaned['income'].map(income_group_mapping)

# **Model 4: include co2, exclude communicable, non_communicable**
X_4 = df_cleaned[['under_nourishment', 'health_expenditure', 'education_expenditure',
                'unemployment', 'co2', 'income_group_encoded', 'corruption']]
y_4 = df_cleaned['life_expectancy']

# Split into training and test datasets
X_train_4, X_test_4, y_train_4, y_test_4 = train_test_split(X_4, y_4, test_size=0.2, random_state=42)

# Standardize features
scaler_4 = StandardScaler()
X_train_scaled_4 = scaler_4.fit_transform(X_train_4)
X_test_scaled_4 = scaler_4.transform(X_test_4)

# Initialize and train the linear regression model
linear_model_4 = LinearRegression()
linear_model_4.fit(X_train_scaled_4, y_train_4)

# Get and print coefficients
coefficients_4 = pd.DataFrame(linear_model_4.coef_, X_4.columns, columns=["Coefficient"])
print(coefficients_4)

# Make predictions
y_pred_4 = linear_model_4.predict(X_test_scaled_4)

# Model evaluation
mse_4 = mean_squared_error(y_test_4, y_pred_4)
print(f"Mean Squared Error (Linear Regression) - Model 4: {mse_4}")

# **Save Model 4**
joblib.dump(linear_model_4, 'linear_model_4.pkl')
joblib.dump(scaler_4, 'scaler_4.pkl')

### "When the value of CO₂ increases by 1 unit, life expectancy increases by 0.478952 units."
# Out:
#                        Coefficient
# under_nourishment        -1.822004
# health_expenditure        1.094248
# education_expenditure     0.339127
# unemployment             -2.182730
# co2                       0.478952
# income_group_encoded      3.659528
# corruption                0.097664
# Mean Squared Error (Linear Regression) - Model 4: 36.94623803848023
# ['scaler_4.pkl']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import joblib

# **Model 4: include co2, exclude communicable, non_communicable**

df_cleaned = df.dropna(subset=['under_nourishment', 'health_expenditure', 'education_expenditure',
                               'unemployment', 'co2', 'income', 'corruption']).copy()

# Processing categorical variable 'income'
income_group_mapping = {'Low income': 1, 'Lower middle income': 2, 'Upper middle income': 3, 'High income': 4}
df_cleaned['income_group_encoded'] = df_cleaned['income'].map(income_group_mapping)

# Define features and target variable for Model 4
X_4 = df_cleaned[['under_nourishment', 'health_expenditure', 'education_expenditure',
                  'unemployment', 'co2', 'income_group_encoded', 'corruption']]
y_4 = df_cleaned['life_expectancy']

# Split into training and test datasets
X_train_4, X_test_4, y_train_4, y_test_4 = train_test_split(X_4, y_4, test_size=0.2, random_state=42)

# Standardize features
scaler_4 = StandardScaler()
X_train_scaled_4 = scaler_4.fit_transform(X_train_4)
X_test_scaled_4 = scaler_4.transform(X_test_4)

# Initialize and train the linear regression model
linear_model_4 = LinearRegression()
linear_model_4.fit(X_train_scaled_4, y_train_4)

# Get and print coefficients
coefficients_4 = pd.DataFrame(linear_model_4.coef_, X_4.columns, columns=["Coefficient"])
print(coefficients_4)

# Make predictions
y_pred_4 = linear_model_4.predict(X_test_scaled_4)

# Model evaluation
mse_4 = mean_squared_error(y_test_4, y_pred_4)
print(f"Mean Squared Error (Linear Regression) - Model 4: {mse_4}")

# Save Model 4
joblib.dump(linear_model_4, 'linear_model_4.pkl')
joblib.dump(scaler_4, 'scaler_4.pkl')

# Interpretation of the coefficient for CO₂
co2_coefficient = linear_model_4.coef_[X_4.columns.get_loc('co2')]
print(f"When the value of CO₂ increases by 1 unit, life expectancy increases by {co2_coefficient:.6f} units.")

# 1. Normal Distribution of Residuals
residuals_4 = y_test_4 - y_pred_4
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
# Residual Plot
sns.scatterplot(x=y_pred_4, y=residuals_4, ax=axes[0])
axes[0].axhline(0, color='r', linestyle='--')
axes[0].set_xlabel('Predicted Values')
axes[0].set_ylabel('Residuals')
axes[0].set_title('Residuals vs Predicted Values')
# Histogram of residuals
sns.histplot(residuals_4, kde=True, ax=axes[1])
axes[1].set_title('Histogram of Residuals')
# Q-Q Plot
stats.probplot(residuals_4, dist="norm", plot=axes[2])
axes[2].set_title('Q-Q Plot of Residuals')
# Adjust layout
plt.tight_layout()
plt.show()

# 3. Check for Heteroscedasticity
X_train_with_const_4 = sm.add_constant(X_train_scaled_4)
linear_model_4_sm = sm.OLS(y_train_4, X_train_with_const_4).fit()
bp_test_4 = sms.het_breuschpagan(linear_model_4_sm.resid, linear_model_4_sm.model.exog)
bp_test_stat_4, bp_test_p_value_4, _, _ = bp_test_4
print(f"Breusch-Pagan Test Statistics: {bp_test_stat_4}")
print(f"Breusch-Pagan Test p-value: {bp_test_p_value_4}")

# 4. Check for Multicollinearity
X_with_const_4 = sm.add_constant(X_train_scaled_4)
vif_data_4 = pd.DataFrame()
vif_data_4["Variable"] = ['const'] + list(X_4.columns)
vif_data_4["VIF"] = [variance_inflation_factor(X_with_const_4, i) for i in range(X_with_const_4.shape[1])]
print(vif_data_4)
# Out:
#                        Coefficient
# under_nourishment        -1.822004
# health_expenditure        1.094248
# education_expenditure     0.339127
# unemployment             -2.182730
# co2                       0.478952
# income_group_encoded      3.659528
# corruption                0.097664
# Mean Squared Error (Linear Regression) - Model 4: 36.94623803848023
# When the value of CO₂ increases by 1 unit, life expectancy increases by 0.478952 units.
# Breusch-Pagan Test Statistics: 31.126501266083405
# Breusch-Pagan Test p-value: 5.8920908320038025e-05
#                 Variable       VIF
# 0                  const  1.000000
# 1      under_nourishment  1.617782
# 2     health_expenditure  1.283143
# 3  education_expenditure  1.191790
# 4           unemployment  1.333768
# 5                    co2  1.037291
# 6   income_group_encoded  1.737469
# 7             corruption  1.221517

# %%
# Evaluate the model for Model 4
from sklearn.metrics import r2_score
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# 1. R²
r2_4 = r2_score(y_test_4, y_pred_4)
print(f"R²: {r2_4}")

# 3. Mean Squared Error (MSE)
X_train_with_const_4 = sm.add_constant(X_train_scaled_4)
linear_model_4_sm = sm.OLS(y_train_4, X_train_with_const_4).fit()
y_train_pred_4 = linear_model_4_sm.predict(X_train_with_const_4)
X_test_with_const_4 = sm.add_constant(X_test_scaled_4)
y_test_pred_4 = linear_model_4_sm.predict(X_test_with_const_4)

train_mse_4 = mean_squared_error(y_train_4, y_train_pred_4)
test_mse_4 = mean_squared_error(y_test_4, y_test_pred_4)

print(f"Training Mean Squared Error: {train_mse_4}")
print(f"Testing Mean Squared Error: {test_mse_4}")
# Out:
# R²: 0.36801679314886293
# Training Mean Squared Error: 33.70363487487027
# Testing Mean Squared Error: 36.94623803848023

# %%
df_cleaned = df.dropna(subset=['under_nourishment', 'health_expenditure', 'education_expenditure',
                'unemployment', 'co2', 'income', 'corruption']).copy()

income_group_mapping = {'Low income': 1, 'Lower middle income': 2, 'Upper middle income': 3, 'High income': 4}
df_cleaned['income_group_encoded'] = df_cleaned['income'].map(income_group_mapping)

# **Model 5: co2 <= 100000**
df_filtered_5 = df_cleaned[df_cleaned['co2'] <= 100000].copy()
X_5 = df_filtered_5[['under_nourishment', 'health_expenditure', 'education_expenditure',
                      'unemployment', 'co2', 'income_group_encoded', 'corruption']]
y_5 = df_filtered_5['life_expectancy']

X_train_5, X_test_5, y_train_5, y_test_5 = train_test_split(X_5, y_5, test_size=0.2, random_state=42)
scaler_5 = StandardScaler()
X_train_scaled_5 = scaler_5.fit_transform(X_train_5)
X_test_scaled_5 = scaler_5.transform(X_test_5)

linear_model_5 = LinearRegression()
linear_model_5.fit(X_train_scaled_5, y_train_5)

coefficients_5 = pd.DataFrame(linear_model_5.coef_, X_5.columns, columns=["Coefficient"])
print(coefficients_5)

y_pred_5 = linear_model_5.predict(X_test_scaled_5)

mse_5 = mean_squared_error(y_test_5, linear_model_5.predict(X_test_scaled_5))
print(f"Mean Squared Error (Linear Regression) - Model 5: {mse_5}")

joblib.dump(linear_model_5, 'linear_model_5.pkl')
joblib.dump(scaler_5, 'scaler_5.pkl')
# Out:
#                        Coefficient
# under_nourishment        -1.492704
# health_expenditure        1.224315
# education_expenditure     0.471521
# unemployment             -1.754382
# co2                       0.959319
# income_group_encoded      3.440224
# corruption                0.493755
# Mean Squared Error (Linear Regression) - Model 5: 30.322733996167337
# ['scaler_5.pkl']

# %%
# 1. Normal Distribution of Residuals
residuals_5 = y_test_5 - y_pred_5
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
# Residual Plot
sns.scatterplot(x=y_pred_5, y=residuals_5, ax=axes[0])
axes[0].axhline(0, color='r', linestyle='--')
axes[0].set_xlabel('Predicted Values')
axes[0].set_ylabel('Residuals')
axes[0].set_title('Residuals vs Predicted Values')
# Histogram of residuals
sns.histplot(residuals_5, kde=True, ax=axes[1])
axes[1].set_title('Histogram of Residuals')
# Q-Q Plot
stats.probplot(residuals_5, dist="norm", plot=axes[2])
axes[2].set_title('Q-Q Plot of Residuals')
# Adjust layout
plt.tight_layout()
plt.show()

# 3. Check for Heteroscedasticity
# Add a constant term
X_train_with_const_5 = sm.add_constant(X_train_scaled_5)
# Fit the linear regression model
linear_model_5_sm = sm.OLS(y_train_5, X_train_with_const_5).fit()
# Breusch-Pagan Test
bp_test_5 = sms.het_breuschpagan(linear_model_5_sm.resid, linear_model_5_sm.model.exog)
# Test result
bp_test_stat_5, bp_test_p_value_5, _, _ = bp_test_5
print(f"Breusch-Pagan Test Statistics: {bp_test_stat_5}")
print(f"Breusch-Pagan Test p-value: {bp_test_p_value_5}")

# 4. Check for Multicollinearity
# Add a constant term to the training data
X_with_const_5 = sm.add_constant(X_train_scaled_5)
# Calculate VIF
vif_data_5 = pd.DataFrame()
vif_data_5["Variable"] = ['const'] + list(X_5.columns)  # Add 'const'
vif_data_5["VIF"] = [variance_inflation_factor(X_with_const_5, i) for i in range(X_with_const_5.shape[1])]
# Display VIF values
print(vif_data_5)
# Out:
# Breusch-Pagan Test Statistics: 31.696943124721734
# Breusch-Pagan Test p-value: 4.622054777871534e-05
#                 Variable       VIF
# 0                  const  1.000000
# 1      under_nourishment  1.705121
# 2     health_expenditure  1.233669
# 3  education_expenditure  1.211050
# 4           unemployment  1.341021
# 5                    co2  1.235419
# 6   income_group_encoded  1.811513
# 7             corruption  1.305572

# %%
from sklearn.metrics import r2_score
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# Evaluate the model for Model 5

# 1. R²: Coefficient of determination
r2_5 = r2_score(y_test_5, y_pred_5)
print(f"R²: {r2_5}")

# 2. Mean Squared Error (MSE) on Training and Testing Data
# Add a constant term to the training data for statsmodels
X_train_with_const_5 = sm.add_constant(X_train_scaled_5)
linear_model_5_sm = sm.OLS(y_train_5, X_train_with_const_5).fit()

# Predict on training data
y_train_pred_5 = linear_model_5_sm.predict(X_train_with_const_5)

# Add a constant term to the test data
X_test_with_const_5 = sm.add_constant(X_test_scaled_5)
# Predict on test data
y_test_pred_5 = linear_model_5_sm.predict(X_test_with_const_5)

# Calculate MSE for training and testing datasets
train_mse_5 = mean_squared_error(y_train_5, y_train_pred_5)
test_mse_5 = mean_squared_error(y_test_5, y_test_pred_5)

# Print the MSE values
print(f"Training Mean Squared Error: {train_mse_5}")
print(f"Testing Mean Squared Error: {test_mse_5}")
# Out:
# R²: 0.3988094827451062
# Training Mean Squared Error: 36.16822924998598
# Testing Mean Squared Error: 30.322733996167372

# %%
# **Model 6: 100000 < co2 <= 400000**
df_filtered_6 = df_cleaned[(df_cleaned['co2'] > 100000) & (df_cleaned['co2'] <= 400000)]
X_6 = df_filtered_6[['under_nourishment', 'health_expenditure', 'education_expenditure',
                      'unemployment', 'co2', 'income_group_encoded', 'corruption']]
y_6 = df_filtered_6['life_expectancy']

X_train_6, X_test_6, y_train_6, y_test_6 = train_test_split(X_6, y_6, test_size=0.2, random_state=42)
scaler_6 = StandardScaler()
X_train_scaled_6 = scaler_6.fit_transform(X_train_6)
X_test_scaled_6 = scaler_6.transform(X_test_6)

linear_model_6 = LinearRegression()
linear_model_6.fit(X_train_scaled_6, y_train_6)

coefficients_6 = pd.DataFrame(linear_model_6.coef_, X_6.columns, columns=["Coefficient"])
print(coefficients_6)

y_pred_6 = linear_model_6.predict(X_test_scaled_6)

mse_6 = mean_squared_error(y_test_6, linear_model_6.predict(X_test_scaled_6))
print(f"Mean Squared Error (Linear Regression) - Model 6: {mse_6}")

joblib.dump(linear_model_6, 'linear_model_6.pkl')
joblib.dump(scaler_6, 'scaler_6.pkl')
# Out:
#                        Coefficient
# under_nourishment        -1.387670
# health_expenditure        0.771879
# education_expenditure     2.073431
# unemployment             -0.706871
# co2                       0.297683
# income_group_encoded      0.000000
# corruption                2.016231
# Mean Squared Error (Linear Regression) - Model 6: 1.3207468717073345
# ['scaler_6.pkl']

# %%
# 1. Normal Distribution of Residuals for Model 6
residuals_6 = y_test_6 - y_pred_6
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Residual Plot
sns.scatterplot(x=y_pred_6, y=residuals_6, ax=axes[0])
axes[0].axhline(0, color='r', linestyle='--')
axes[0].set_xlabel('Predicted Values')
axes[0].set_ylabel('Residuals')
axes[0].set_title('Residuals vs Predicted Values')

# Histogram of residuals
sns.histplot(residuals_6, kde=True, ax=axes[1])
axes[1].set_title('Histogram of Residuals')

# Q-Q Plot
stats.probplot(residuals_6, dist="norm", plot=axes[2])
axes[2].set_title('Q-Q Plot of Residuals')

# Adjust layout
plt.tight_layout()
plt.show()

# 2. Check for Heteroscedasticity for Model 6
# Add a constant term to the training data
X_train_with_const_6 = sm.add_constant(X_train_scaled_6)

# Fit the linear regression model
linear_model_6_sm = sm.OLS(y_train_6, X_train_with_const_6).fit()

# Breusch-Pagan Test for heteroscedasticity
bp_test_6 = sms.het_breuschpagan(linear_model_6_sm.resid, linear_model_6_sm.model.exog)

# Test result
bp_test_stat_6, bp_test_p_value_6, _, _ = bp_test_6
print(f"Breusch-Pagan Test Statistics: {bp_test_stat_6}")
print(f"Breusch-Pagan Test p-value: {bp_test_p_value_6}")

# 3. Check for Multicollinearity for Model 6
# Add a constant term to the training data
X_with_const_6 = sm.add_constant(X_train_scaled_6)

# Calculate VIF
vif_data_6 = pd.DataFrame()
vif_data_6["Variable"] = ['const'] + list(X_6.columns)  # Add 'const'
vif_data_6["VIF"] = [variance_inflation_factor(X_with_const_6, i) for i in range(X_with_const_6.shape[1])]

# Display VIF values
print(vif_data_6)
# Out:
# Breusch-Pagan Test Statistics: 12.954522539976754
# Breusch-Pagan Test p-value: 0.07322422384671226
#                 Variable        VIF
# 0                  const   1.000000
# 1      under_nourishment  11.867364
# 2     health_expenditure  20.749376
# 3  education_expenditure  17.404748
# 4           unemployment   3.590146
# 5                    co2   3.638899
# 6   income_group_encoded        NaN
# 7             corruption   2.656069
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss

# %%
from sklearn.metrics import r2_score
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# Evaluate the model for Model 6

# 1. R²: Coefficient of determination
r2_6 = r2_score(y_test_6, y_pred_6)
print(f"R²: {r2_6}")

# 2. Mean Squared Error (MSE) on Training and Testing Data
# Add a constant term to the training data for statsmodels
X_train_with_const_6 = sm.add_constant(X_train_scaled_6)
linear_model_6_sm = sm.OLS(y_train_6, X_train_with_const_6).fit()

# Predict on training data
y_train_pred_6 = linear_model_6_sm.predict(X_train_with_const_6)

# Add a constant term to the test data
X_test_with_const_6 = sm.add_constant(X_test_scaled_6)
# Predict on test data
y_test_pred_6 = linear_model_6_sm.predict(X_test_with_const_6)

# Calculate MSE for training and testing datasets
train_mse_6 = mean_squared_error(y_train_6, y_train_pred_6)
test_mse_6 = mean_squared_error(y_test_6, y_test_pred_6)

# Print the MSE values
print(f"Training Mean Squared Error: {train_mse_6}")
print(f"Testing Mean Squared Error: {test_mse_6}")
# Out:
# R²: 0.9022410833293001
# Training Mean Squared Error: 2.104333976610348
# Testing Mean Squared Error: 1.3207468717073576

# %%
# **Model 7: CO2 > 100000**
df_filtered_7 = df_cleaned[(df_cleaned['co2'] > 100000)]
X_7 = df_filtered_7[['under_nourishment', 'health_expenditure', 'education_expenditure',
                      'unemployment', 'co2', 'income_group_encoded', 'corruption']]
y_7 = df_filtered_7['life_expectancy']

X_train_7, X_test_7, y_train_7, y_test_7 = train_test_split(X_7, y_7, test_size=0.2, random_state=42)
scaler_7 = StandardScaler()
X_train_scaled_7 = scaler_7.fit_transform(X_train_7)
X_test_scaled_7 = scaler_7.transform(X_test_7)

linear_model_7 = LinearRegression()
linear_model_7.fit(X_train_scaled_7, y_train_7)

coefficients_7 = pd.DataFrame(linear_model_7.coef_, X_7.columns, columns=["Coefficient"])
print(coefficients_7)

y_pred_7 = linear_model_7.predict(X_test_scaled_7)

mse_7 = mean_squared_error(y_test_7, linear_model_7.predict(X_test_scaled_7))
print(f"Mean Squared Error (Linear Regression) - Model 7: {mse_7}")

joblib.dump(linear_model_7, 'linear_model_7.pkl')
joblib.dump(scaler_7, 'scaler_7.pkl')
# Out:
#                        Coefficient
# under_nourishment        -0.966504
# health_expenditure       -0.861318
# education_expenditure     3.487299
# unemployment             -0.684790
# co2                      -1.325353
# income_group_encoded      0.000000
# corruption                2.057482
# Mean Squared Error (Linear Regression) - Model 7: 3.4619407018097217
# ['scaler_7.pkl']

# %%
# 1. Normal Distribution of Residuals
residuals_7 = y_test_7 - y_pred_7
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
# Residual Plot
sns.scatterplot(x=y_pred_7, y=residuals_7, ax=axes[0])
axes[0].axhline(0, color='r', linestyle='--')
axes[0].set_xlabel('Predicted Values')
axes[0].set_ylabel('Residuals')
axes[0].set_title('Residuals vs Predicted Values')

# Histogram of residuals
sns.histplot(residuals_7, kde=True, ax=axes[1])
axes[1].set_title('Histogram of Residuals')

# Q-Q Plot
stats.probplot(residuals_7, dist="norm", plot=axes[2])
axes[2].set_title('Q-Q Plot of Residuals')

# Adjust layout
plt.tight_layout()
plt.show()

# 3. Check for Heteroscedasticity
# Add a constant term
X_train_with_const_7 = sm.add_constant(X_train_scaled_7)
# Fit the linear regression model
linear_model_7_sm = sm.OLS(y_train_7, X_train_with_const_7).fit()
# Breusch-Pagan Test
bp_test_7 = sms.het_breuschpagan(linear_model_7_sm.resid, linear_model_7_sm.model.exog)
# Test result
bp_test_stat_7, bp_test_p_value_7, _, _ = bp_test_7
print(f"Breusch-Pagan Test Statistics: {bp_test_stat_7}")
print(f"Breusch-Pagan Test p-value: {bp_test_p_value_7}")

# 4. Check for Multicollinearity
# Add a constant term to the training data
X_with_const_7 = sm.add_constant(X_train_scaled_7)
# Calculate VIF
vif_data_7 = pd.DataFrame()
vif_data_7["Variable"] = ['const'] + list(X_7.columns)  # Add 'const'
vif_data_7["VIF"] = [variance_inflation_factor(X_with_const_7, i) for i in range(X_with_const_7.shape[1])]
# Display VIF values
print(vif_data_7)

# Save the model and scaler
joblib.dump(linear_model_7, 'linear_model_7.pkl')
joblib.dump(scaler_7, 'scaler_7.pkl')
# Out:
# Breusch-Pagan Test Statistics: 10.21972372198733
# Breusch-Pagan Test p-value: 0.17646010769160284
#                 Variable        VIF
# 0                  const   1.000000
# 1      under_nourishment  10.537800
# 2     health_expenditure  13.698103
# 3  education_expenditure  18.806609
# 4           unemployment   1.804382
# 5                    co2   3.410567
# 6   income_group_encoded        NaN
# 7             corruption   5.952164
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# ['scaler_7.pkl']

# %%
from sklearn.metrics import r2_score
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# Evaluate the model for Model 7

# 1. R²: Coefficient of determination
r2_7 = r2_score(y_test_7, y_pred_7)
print(f"R²: {r2_7}")

# 2. Mean Squared Error (MSE) on Training and Testing Data
# Add a constant term to the training data for statsmodels
X_train_with_const_7 = sm.add_constant(X_train_scaled_7)
linear_model_7_sm = sm.OLS(y_train_7, X_train_with_const_7).fit()

# Predict on training data
y_train_pred_7 = linear_model_7_sm.predict(X_train_with_const_7)

# Add a constant term to the test data
X_test_with_const_7 = sm.add_constant(X_test_scaled_7)
# Predict on test data
y_test_pred_7 = linear_model_7_sm.predict(X_test_with_const_7)

# Calculate MSE for training and testing datasets
train_mse_7 = mean_squared_error(y_train_7, y_train_pred_7)
test_mse_7 = mean_squared_error(y_test_7, y_test_pred_7)

# Print the MSE values
print(f"Training Mean Squared Error: {train_mse_7}")
print(f"Testing Mean Squared Error: {test_mse_7}")
# Out:
# R²: 0.8468009809616499
# Training Mean Squared Error: 1.8347810239777427
# Testing Mean Squared Error: 3.4619407018097896
