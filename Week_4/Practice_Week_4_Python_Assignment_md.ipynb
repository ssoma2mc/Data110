# %% [markdown]
# <a href="https://colab.research.google.com/github/ssoma2mc/Data110/blob/main/Practice_Week_4_Python_Assignment_md.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crime Data Visualization (2022-2023)
#
#
#
# In this assignment, we will analyze real-world crime data from 2022 to 2023, sourced from the **FBI's Crime Data** as reported by the Brennan Center. According to the Brennan Center’s analysis, most crimes, including murder, have seen significant drops in 2023.
#
# Source: [FBI Data Confirms Drop in Most Crimes in 2023, Especially Murders](https://www.brennancenter.org/our-work/analysis-opinion/fbi-data-confirms-drop-most-crimes-2023-especially-murders)
#
# ## Dataset
#
# | **Offense**                  | **Offenses per 100,000 People (2023)** | **Change in Offenses per 100,000 People (2022-2023)** |
# |------------------------------|----------------------------------------|-------------------------------------------------------|
# | Aggravated Assault            | 264.1                                  | -3.3                                                  |
# | Burglary                      | 250.7                                  | -8.1                                                  |
# | Larceny                       | 1,347.2                                | -4.9                                                  |
# | Motor Vehicle Theft           | 318.7                                  | +12.0                                                 |
# | Murder                        | 5.7                                    | -12.0                                                 |
# | Rape (revised definition)     | 38.0                                   | -9.8                                                  |
# | Robbery                       | 66.5                                   | -0.8                                                  |
#
#
# ---

# %% [markdown]
# ## Task 1: Basic Bar Chart for Crime Rates in 2023
#
# In this task, you will create a **bar chart** showing the offense rates per 100,000 people for each type of crime in 2023.
#
# ### Instructions:
# - Create a bar chart for crime rates in 2023.
# - Customize the bar colors and add gridlines.
# - Label the axes and add a title.
#
# ---

# %%
# Data for the crimes (Change in Offenses per 100,000 People 2022-2023)
crimes = ['Aggravated Assault', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Murder', 'Rape (revised definition)', 'Robbery']
offenses_2023 = [264.1, 250.7, 1347.2, 318.7, 5.7, 38.0, 66.5]
change_in_offenses = [-3.3, -8.1, -4.9, 12.0, -12.0, -9.8, -0.8]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import seaborn as sns

# %%
#  Answer the questions with the ggplot format first, then try to use seaborn colors
plt.style.use('ggplot')

# %%
# Data for the crimes
crimes = ['Aggravated Assault', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Murder', 'Rape (revised definition)', 'Robbery']
offenses_2023 = [264.1, 250.7, 1347.2, 318.7, 5.7, 38.0, 66.5]
change_in_offenses = [-3.3, -8.1, -4.9, 12.0, -12.0, -9.8, -0.8]

# Create a DataFrame
#df = pd.DataFrame({
#    'Crime': crimes,
#    'Offenses per 100,000': offenses_2023,
#    'Change in offenses': change_in_offenses
#  })

# %%
# Sort the crimes and offenses in descending order based on offenses
sorted_crimes, sorted_offenses = zip(*sorted(zip(crimes, offenses_2023), key=lambda x: x[1], reverse=True))

# Create the bar plot with vertical bars using matplotlib
plt.figure(figsize=(10, 6))
bars = plt.bar(sorted_crimes, sorted_offenses)

# Add annotations to each bar for clarity
for index, value in enumerate(sorted_offenses):
    plt.text(index, value + 10, f'{value:.1f}', ha='center', color='black', fontweight='bold')

# Customize the plot
plt.xlabel('Type of Crime', fontsize=12, fontweight='bold')
plt.ylabel('Offenses per 100,000 People', fontsize=12, fontweight='bold')
plt.title('Crime Rates in 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')
plt.grid(True, axis='y', linestyle='--', linewidth=0.7)

# Show the plot
plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# Manually define colors for each bar
#colors = ['#440154', '#482576', '#3E4A89', '#31688E', '#26828E', '#1F9D8A', '#A0D86E']
#bars = plt.bar(sorted_crimes, sorted_offenses, color=colors)

# %%
# Data for the crimes
crimes = ['Aggravated Assault', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Murder', 'Rape (revised definition)', 'Robbery']
offenses_2023 = [264.1, 250.7, 1347.2, 318.7, 5.7, 38.0, 66.5]

# Sort the crimes and offenses in descending order based on offenses
sorted_crimes, sorted_offenses = zip(*sorted(zip(crimes, offenses_2023), key=lambda x: x[1], reverse=False))

# Create the horizontal bar plot using matplotlib
plt.figure(figsize=(10, 6))
bars = plt.barh(sorted_crimes, sorted_offenses) #Use plt.barh() instead of plt.bar()

# Add annotations to each bar for clarity
for index, value in enumerate(sorted_offenses):
    plt.text(value + 10, index, f'{value:.1f}', va='center', color='black', fontweight='bold')

# Customize the plot
plt.xlabel('Offenses per 100,000 People', fontsize=12, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=12, fontweight='bold')
plt.title('Crime Rates in 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')
plt.grid(True, axis='x', linestyle='--', linewidth=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %%
all_colors = list(colors.CSS4_COLORS.keys())
blue_colors = [color for color in all_colors if 'blue' in color]
print(blue_colors)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-168-3faa11fa13fd> in <cell line: 0>()
# ----> 1 all_colors = list(colors.CSS4_COLORS.keys())
#       2 blue_colors = [color for color in all_colors if 'blue' in color]
#       3 print(blue_colors)
#
# AttributeError: 'list' object has no attribute 'CSS4_COLORS'

# %%
# Data for the crimes
crimes = ['Aggravated Assault', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Murder', 'Rape (revised definition)', 'Robbery']
offenses_2023 = [264.1, 250.7, 1347.2, 318.7, 5.7, 38.0, 66.5]

# Sort the crimes and offenses in descending order based on offenses
sorted_crimes, sorted_offenses = zip(*sorted(zip(crimes, offenses_2023), key=lambda x: x[1], reverse=False))

# Customize the bar colors: heavy crimes (Murder, Aggravated Assault) are dark blue, others are blue
colors = []
for crime in sorted_crimes:
    if crime in ['Murder', 'Aggravated Assault']:  # Set heavy crimes to dark blue
        colors.append('midnightblue')
    else:  # Set lighter crimes to blue
        colors.append('steelblue')

# Create the horizontal bar plot using matplotlib
plt.figure(figsize=(10, 6))

# Create the bars with the selected colors
bars = plt.barh(sorted_crimes, sorted_offenses, color=colors)

# Add annotations to each bar for clarity
for index, value in enumerate(sorted_offenses):
    plt.text(value + 10, index, f'{value:.1f}', va='center', color='black', fontweight='bold')

# Customize the plot
plt.xlabel('Offenses per 100,000 People', fontsize=12, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=12, fontweight='bold')
plt.title('Crime Rates in 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')
plt.grid(True, axis='x', linestyle='--', linewidth=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %%
# Sort the crimes and offenses in descending order based on offenses
sorted_crimes, sorted_offenses = zip(*sorted(zip(crimes, offenses_2023), key=lambda x: x[1], reverse=True))

# Customize the bar colors: heavy crimes (Murder, Aggravated Assault) are orange, others are blue
# orange of ggplot: #D88C3D
# blue of ggplot: #6B9AC4
colors = []
for crime in sorted_crimes:
    if crime in ['Murder', 'Aggravated Assault']:  # Set heavy crimes to orange
        colors.append('#E69F00')
    else:  # Set lighter crimes to blue
        colors.append('#6B9AC4')

# Create the vertical bar plot using matplotlib
plt.figure(figsize=(10, 6))

# Create the bars with the selected colors
bars = plt.bar(sorted_crimes, sorted_offenses, color=colors)

# Add annotations to each bar for clarity
for index, value in enumerate(sorted_offenses):
    plt.text(index, value + 10, f'{value:.1f}', ha='center', va='bottom', color='black', fontweight='bold')

# Customize the plot
plt.xlabel('Offenses per 100,000 People', fontsize=12, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=12, fontweight='bold')
plt.title('Crime Rates in 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')
plt.grid(True, axis='y', linestyle='--', linewidth=0.7)

# Rotate the x-axis labels to avoid overlap
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %% [markdown]
# ## Task 2: Change in Crime Rates (2022 vs. 2023) with Unique Colors
#
# In this task, you will create a **horizontal bar chart** that visualizes the **percentage change** in offense rates from 2022 to 2023 for each crime type. Each bar should have a unique color for better distinction.
#
# ### Instructions:
# - Create a horizontal bar chart showing the **change in offense rates**.
# - Assign a unique color to each crime type.
# - Label the axes and add a title.

# %%
# Data for the crimes (Offenses per 100,000 People 2023)
crimes = ['Aggravated Assault', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Murder', 'Rape (revised definition)', 'Robbery']
offenses_2023 = [264.1, 250.7, 1347.2, 318.7, 5.7, 38.0, 66.5]
change_in_offenses = [-3.3, -8.1, -4.9, 12.0, -12.0, -9.8, -0.8]

# Sort the data by change_in_offenses in descending order
sorted_crimes, sorted_offenses_2023, sorted_change_in_offenses = zip(
    *sorted(zip(crimes, offenses_2023, change_in_offenses), key=lambda x: x[2], reverse=True)
)

# Colors in the specified order
orange_1 = "#C77C4A"  # Dark Orange
orange_2 = "#E4A96B"  # Light Orange

blue_1 = "#1F3A52"  # Dark Blue
blue_2 = "#2C5A83"  # Darker Blue
blue_3 = "#436D9F" # Blue
blue_4 = "#5A8BCA"  # Lighter Blue
blue_5 = "#6CB4E1"  # Light Blue

# Assign colors based on the given order (with specific mapping)
#print(sorted_crimes) Mannuary adjusted
#('Motor Vehicle Theft', 'Robbery', 'Aggravated Assault', 'Larceny', 'Burglary', 'Rape (revised definition)', 'Murder')
colors = [blue_5, blue_4, orange_2, blue_3, blue_2, blue_1, orange_1]

# Create the horizontal bar plot using matplotlib
plt.figure(figsize=(10, 6))

# Create the bars with the selected colors
bars = plt.barh(sorted_crimes, sorted_change_in_offenses, color=colors)

# Add annotations to each bar for clarity
for index, value in enumerate(sorted_change_in_offenses):
    plt.text(value + 0.5, index, f'{value:.1f}', va='center', color='black', fontweight='bold')

# Customize the plot
plt.xlabel('Change in Offenses per 100,000 People (2022-2023)', fontsize=12, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=12, fontweight='bold')
plt.title('Change in Crime Rates in 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')
plt.grid(True, axis='x', linestyle='--', linewidth=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %%
# Challenge loop →failed

# Sort the data by change_in_offenses in descending order
sorted_crimes, sorted_offenses_2023, sorted_change_in_offenses = zip(
    *sorted(zip(crimes, offenses_2023, change_in_offenses), key=lambda x: x[2], reverse=True)
)

# Assign unique colors for each crime type
orange_1 = "#C77C4A"  # Dark Orange
orange_2 = "#E4A96B"  # Light Orange

blue_1 = "#1F3A52"  # Dark Blue
blue_2 = "#2C5A83"  # Darker Blue
blue_3 = "#436D9F" # Blue
blue_4 = "#5A8BCA"  # Lighter Blue
blue_5 = "#6CB4E1"  # Light Blue

# Assign colors based on crime type
colors = []
for crime in sorted_crimes:
    if crime in ['Murder', 'Aggravated Assault']:  # Heavy crimes
        colors.append(orange_2)  # Lighter orange for heavy crimes
    else:  # Non-heavy crimes
        colors.append(blue_1)  # Dark Blue for non-heavy crimes

# Create the horizontal bar plot using matplotlib
plt.figure(figsize=(10, 6))

# Create the bars with the selected colors
bars = plt.barh(sorted_crimes, sorted_change_in_offenses, color=colors)

# Add annotations to each bar for clarity
for index, value in enumerate(sorted_change_in_offenses):
    plt.text(value + 0.5, index, f'{value:.1f}', va='center', color='black', fontweight='bold')

# Customize the plot
plt.xlabel('Change in Offenses per 100,000 People (2022-2023)', fontsize=12, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=12, fontweight='bold')
plt.title('Change in Crime Rates in 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')
plt.grid(True, axis='x', linestyle='--', linewidth=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %% [markdown]
# ### Additional Instructions:
# 1. **Why does this bar graph make more sense than Task 1's bar graph?**
#    - Think about how **absolute numbers** (like total crime rates) might be misleading compared to **percentage changes**.
#    - Explain why seeing the **change** over time is more insightful than just seeing the total number of offenses for a single year.

# %%
# Calculate the 2022 offenses based on the change
offenses_2022 = [offense / (1 + (change / 100)) for offense, change in zip(offenses_2023, change_in_offenses)]

# Sort the data by offenses_2023 in ascending order
sorted_crimes, sorted_offenses_2022, sorted_offenses_2023 = zip(
    *sorted(zip(crimes, offenses_2022, offenses_2023), key=lambda x: x[1], reverse=False)
)

# Set up the colors for 2022 and 2023
color_2022 = blue_4  # Lighter Blue for 2022
color_2023 = orange_1  # Dark Orange for 2023

# Create the horizontal bar plot with two bars per crime (2022 and 2023)
plt.figure(figsize=(10, 6))

# Set the positions of the bars
bar_width = 0.35
index = np.arange(len(sorted_crimes))

# Plot the bars for 2022 and 2023 offenses
plt.barh(index - bar_width / 2, sorted_offenses_2022, bar_width, color=color_2022, label='2022')
plt.barh(index + bar_width / 2, sorted_offenses_2023, bar_width, color=color_2023, label='2023')

# Add annotations to each bar for clarity
for i, (value_2022, value_2023) in enumerate(zip(sorted_offenses_2022, sorted_offenses_2023)):
    plt.text(value_2022 + 10, i - bar_width / 2, f'{value_2022:.1f}', va='center', color='black', fontweight='bold')
    plt.text(value_2023 + 10, i + bar_width / 2, f'{value_2023:.1f}', va='center', color='black', fontweight='bold')

# Customize the plot
plt.xlabel('Offenses per 100,000 People', fontsize=12, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=12, fontweight='bold')
plt.title('Crime Rates in 2022 and 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')
plt.yticks(index, sorted_crimes)
plt.legend()

# Grid lines for better readability
plt.grid(True, axis='x', linestyle='--', linewidth=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()



# This graph explains why representing changes is more representative.

# %% [markdown]
# I created a bar chart showing the crime rates for 2022 and 2023 to answer this question. As a result, it becomes clear that displaying absolute numbers makes it difficult to show the difference. While we can show the decrease in numbers, comparing them is inappropriate because the number of occurrences varies greatly for each crime. Therefore, I conclude that comparing the decrease in numbers is the appropriate approach.

# %% [markdown]
# ### Additional Instructions:
# 2. **Improve the clarity of your bar graph**:
#    - Create **multiple versions** of the bar chart for Task 2, each time making the chart more **clear and readable**.
#    - Experiment with different color schemes, labels, and gridlines.
#    - In each iteration, focus on improving the ease with which someone can quickly understand the trends in crime rates.

# %%
# This is my Task 2 graph. I am going to use seaborn and make it more clear and readable.

# Data for the crimes (Offenses per 100,000 People 2023)
crimes = ['Aggravated Assault', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Murder', 'Rape (revised definition)', 'Robbery']
offenses_2023 = [264.1, 250.7, 1347.2, 318.7, 5.7, 38.0, 66.5]
change_in_offenses = [-3.3, -8.1, -4.9, 12.0, -12.0, -9.8, -0.8]

# Sort the data by change_in_offenses in descending order
sorted_crimes, sorted_offenses_2023, sorted_change_in_offenses = zip(
    *sorted(zip(crimes, offenses_2023, change_in_offenses), key=lambda x: x[2], reverse=True)
)

# Colors in the specified order
orange_1 = "#C77C4A"  # Dark Orange
orange_2 = "#E4A96B"  # Light Orange

blue_1 = "#1F3A52"  # Dark Blue
blue_2 = "#2C5A83"  # Darker Blue
blue_3 = "#436D9F" # Blue
blue_4 = "#5A8BCA"  # Lighter Blue
blue_5 = "#6CB4E1"  # Light Blue

# Assign colors based on the given order (with specific mapping)
#print(sorted_crimes) Mannuary adjusted
#('Motor Vehicle Theft', 'Robbery', 'Aggravated Assault', 'Larceny', 'Burglary', 'Rape (revised definition)', 'Murder')
colors = [blue_5, blue_4, orange_2, blue_3, blue_2, blue_1, orange_1]

# Create the horizontal bar plot using matplotlib
plt.figure(figsize=(10, 6))

# Create the bars with the selected colors
bars = plt.barh(sorted_crimes, sorted_change_in_offenses, color=colors)

# Add annotations to each bar for clarity
for index, value in enumerate(sorted_change_in_offenses):
    plt.text(value + 0.5, index, f'{value:.1f}', va='center', color='black', fontweight='bold')

# Customize the plot
plt.xlabel('Change in Offenses per 100,000 People (2022-2023)', fontsize=12, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=12, fontweight='bold')
plt.title('Change in Crime Rates in 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')
plt.grid(True, axis='x', linestyle='--', linewidth=0.7)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
#####color schemes
#Use "Seaborn color palettes" https://seaborn.pydata.org/tutorial/color_palettes.html
# deep(default), muted, pastel, bright, dark, colorblind

#current_palette = sns.color_palette("deep", n_colors=24)
#sns.palplot(current_palette)

# Coloful, but this is not proper for representing 'crime'

# Data for the crimes (Offenses per 100,000 People 2023)
crimes = ['Aggravated Assault', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Murder', 'Rape (revised definition)', 'Robbery']
offenses_2023 = [264.1, 250.7, 1347.2, 318.7, 5.7, 38.0, 66.5]
change_in_offenses = [-3.3, -8.1, -4.9, 12.0, -12.0, -9.8, -0.8]

# Sort the data by change_in_offenses in descending order
sorted_crimes, sorted_offenses_2023, sorted_change_in_offenses = zip(
    *sorted(zip(crimes, offenses_2023, change_in_offenses), key=lambda x: x[2], reverse=False)
)

# Use a dark color palette
palette = sns.color_palette("deep", len(sorted_crimes))  # Use a dark color palette

# Create the horizontal bar plot using Seaborn
plt.figure(figsize=(10, 6))

# Create the bars with the selected colors from Seaborn's palette
sns.barplot(y=list(sorted_crimes), x=list(sorted_change_in_offenses), palette=palette)

# Add annotations to each bar for clarity
for index, value in enumerate(sorted_change_in_offenses):
    plt.text(value + 0.5, index, f'{value:.1f}', va='center', color='black', fontweight='bold')

# Customize the plot with more readable labels
plt.xlabel('Change in Offenses per 100,000 People (2022-2023)', fontsize=12, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=12, fontweight='bold')
plt.title('Change in Crime Rates in 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')

# Grid lines for better readability
plt.grid(True, axis='x', linestyle='--', linewidth=0.7)

# Adjust layout to prevent clipping
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-141-7f6697dbf57d>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=list(sorted_crimes), x=list(sorted_change_in_offenses), palette=palette)

# %%
#####color schemes
#Use "Seaborn color palettes" https://seaborn.pydata.org/tutorial/color_palettes.html
# deep(default), muted, pastel, bright, dark, colorblind

#current_palette = sns.color_palette("crest", n_colors=24)
#sns.palplot(current_palette)

# Sort the data by change_in_offenses in descending order
sorted_crimes, sorted_offenses_2023, sorted_change_in_offenses = zip(
    *sorted(zip(crimes, offenses_2023, change_in_offenses), key=lambda x: x[2], reverse=False)
)

# Use a dark color palette
palette = sns.color_palette("crest", len(sorted_crimes))  # Use a dark color palette

# Create the horizontal bar plot using Seaborn
plt.figure(figsize=(10, 6))

# Create the bars with the selected colors from Seaborn's palette
sns.barplot(y=list(sorted_crimes), x=list(sorted_change_in_offenses), palette=palette)

# Add annotations to each bar for clarity
for index, value in enumerate(sorted_change_in_offenses):
    plt.text(value + 0.5, index, f'{value:.1f}', va='center', color='black', fontweight='bold')

# Customize the plot with more readable labels
plt.xlabel('Change in Offenses per 100,000 People (2022-2023)', fontsize=12, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=12, fontweight='bold')
plt.title('Change in Crime Rates in 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')

# Grid lines for better readability
plt.grid(True, axis='x', linestyle='--', linewidth=0.7)

# Adjust layout to prevent clipping
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-142-1659e3d7920a>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=list(sorted_crimes), x=list(sorted_change_in_offenses), palette=palette)

# %%
##### labels

# Adjust x-axis, y-axis labels
# Change the collar of annotations to each bar using if/else

# Sort the data by change_in_offenses in ascending order
sorted_crimes, sorted_offenses_2023, sorted_change_in_offenses = zip(
    *sorted(zip(crimes, offenses_2023, change_in_offenses), key=lambda x: x[2], reverse=False)
)

# Color palette
palette = sns.color_palette("crest", len(sorted_crimes))

# Create the horizontal bar plot using Seaborn
plt.figure(figsize=(12, 8))  # Increased figure size to make the labels readable

# Create the bars with the selected colors from Seaborn's palette
sns.barplot(y=list(sorted_crimes), x=list(sorted_change_in_offenses), palette=palette)

# Add annotations to each bar for clarity
for index, value in enumerate(sorted_change_in_offenses):
    # Set annotation color to black
    plt.text(value + 0.5 if value >= 0 else value - 0.5,
             index, f'{value:.1f}', va='center', color='black', fontweight='bold', fontsize=12,
             ha='left' if value >= 0 else 'right')  # Adjust horizontal alignment for negative/positive values

# Customize the plot with larger labels for better readability
plt.xlabel('Change in Offenses per 100,000 People (2022-2023)', fontsize=14, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=14, fontweight='bold')
plt.title('Change in Crime Rates in 2023 (Offenses per 100,000 People)', fontsize=16, fontweight='bold')

# Customize gridlines with dashed lines and larger spacing
plt.grid(True, axis='x', linestyle='--', linewidth=0.7)

# Set x-axis range from -14 to 14
plt.xlim(-14, 14)  # Set the x-axis range explicitly

# Adjust the spacing of the y-axis labels for readability
plt.tight_layout()  # Ensures there is no clipping of labels

# Show the plot
plt.show()
# Out:
# <ipython-input-143-048a402ba2e3>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=list(sorted_crimes), x=list(sorted_change_in_offenses), palette=palette)

# %%
#####gridlines
# griclines are OK.

# %% [markdown]
# ## Optional Task: Combined Bar Chart for Crime Rates in 2022 and 2023
#
# In this optional task, you will create a **combined bar chart** that shows the crime rates for both **2022 and 2023**.
#
# ### Instructions:
# - Calculate the **crime rates for 2022** based on the 2023 values and the percentage changes provided.
# - Create a **combined bar chart** that compares the crime rates for 2022 and 2023 for each offense type.
# - Use different colors to distinguish between the years 2022 and 2023.
# - Label the axes and add a title.
# - Add a legend to indicate which bars represent which year.
#
# ### Remark:
# - You are required to complete this task in **Google Colab**. Name your file **Data110_YourName_Week4**.
# - When submitting your assignment, upload your code, calculations, and final bar chart in the Google Colab Notebook.

# %%
# I have made the graph for additional task 1.
# I rewrite the graph using 'seaborn-v0_8-white grid' and 'Seaborn color palettes'

plt.style.use('seaborn-v0_8-whitegrid')

current_palette = sns.color_palette("dark", n_colors=10)
#sns.palplot(current_palette)

# Data for the crimes (Offenses per 100,000 People 2023)
crimes = ['Aggravated Assault', 'Burglary', 'Larceny', 'Motor Vehicle Theft', 'Murder', 'Rape (revised definition)', 'Robbery']
offenses_2023 = [264.1, 250.7, 1347.2, 318.7, 5.7, 38.0, 66.5]
change_in_offenses = [-3.3, -8.1, -4.9, 12.0, -12.0, -9.8, -0.8]

# Calculate the 2022 offenses based on the change
offenses_2022 = [offense / (1 + (change / 100)) for offense, change in zip(offenses_2023, change_in_offenses)]

# Sort the data by offenses_2023 in ascending order
sorted_crimes, sorted_offenses_2022, sorted_offenses_2023 = zip(
    *sorted(zip(crimes, offenses_2022, offenses_2023), key=lambda x: x[1], reverse=False)
)

# Create the horizontal bar plot with two bars per crime (2022 and 2023)
plt.figure(figsize=(10, 6))

# Set the positions of the bars
bar_width = 0.35
index = np.arange(len(sorted_crimes))

# Plot the bars for 2022 and 2023 offenses using Seaborn's color palette
plt.barh(index - bar_width / 2, sorted_offenses_2022, bar_width, color=current_palette[8], label='2022')
plt.barh(index + bar_width / 2, sorted_offenses_2023, bar_width, color=current_palette[9], label='2023')

# Add annotations to each bar for clarity
for i, (value_2022, value_2023) in enumerate(zip(sorted_offenses_2022, sorted_offenses_2023)):
    plt.text(value_2022 + 10, i - bar_width / 2, f'{value_2022:.1f}', va='center', color='black', fontweight='bold')
    plt.text(value_2023 + 10, i + bar_width / 2, f'{value_2023:.1f}', va='center', color='black', fontweight='bold')

# Customize the plot
plt.xlabel('Offenses per 100,000 People', fontsize=12, fontweight='bold')
plt.ylabel('Type of Crime', fontsize=12, fontweight='bold')
plt.title('Crime Rates in 2022 and 2023 (Offenses per 100,000 People)', fontsize=14, fontweight='bold')
plt.yticks(index, sorted_crimes)
plt.legend()

# Grid lines for better readability
plt.grid(True, axis='x', linestyle='--', linewidth=0.7)

# Set x-axis range from 0 to 1600
plt.xlim(0, 1600)  # Set the x-axis range explicitly

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()
