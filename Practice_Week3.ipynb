# %% [markdown]
# <a href="https://colab.research.google.com/github/ssoma2mc/Data110/blob/main/Practice_Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # Task 10
 # How to write "( x \to \infty \)" in the text?
 # How to handle for  𝑥=0, appropriately?
 # Could you teach me 'sinc' function?

# %% [markdown]
# # Week 3: Matplotlib Line and Scatter Plots Assignment
#
# ## Overview
#
# In this assignment, you'll practice creating various line and scatter plots using Matplotlib in Python. You'll work with different mathematical functions to create diverse and interesting plots, and explore different plotting styles.
#
# ## Tasks
#
# ### 1. Setup and Styles
# - Import the necessary libraries (Matplotlib and NumPy)
# - Use the following code to print out all available styles:
#   ```python
#   import matplotlib.pyplot as plt
#   print(plt.style.available)
#   ```
# - Set the default style to 'seaborn-whitegrid'
# - Choose one additional style from the available list to use later in the assignment

# %%
import matplotlib.pyplot as plt
print(plt.style.available)

# Setting the default style to 'seaborn-whitegrid'→seaborn-v0_8-whitegrid
plt.style.use('seaborn-v0_8-whitegrid')

# Choosing one additional style from the available list (→'seaborn-v0_8-darkgrid')
# plt.stylet.use('seaborn-v0_8-darkgrid')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ### 2. Basic Line Plot
# - Create a plot of the quadratic function $f(x) = x^2 - 2x + 1$ over the range $[-2, 4]$
# - Use `plt.plot()` to create the plot

# %%
import numpy as np

# Generate values for x in the range [-2, 4]
x = np.linspace(-2, 4, 400)

# Compute the corresponding y values for the quadratic function f(x) = x^2 - 2x + 1
y = x**2 - 2*x + 1

# Create the plot
plt.plot(x, y, label="f(x) = x^2 - 2x + 1", color='b')

# Add labels and a title
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of f(x) = x^2 - 2x + 1')

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### 3. Multiple Lines
# - Create a plot with the following three functions on the same graph:
#   - $f(x) = x^3$
#   - $g(x) = e^x$
#   - $h(x) = \log(x)$ (for $x > 0$)
# - Use different colors for each line
# - Add a legend to distinguish between the functions

# %%
# Generate values for x
x1 = np.linspace(-3, 3, 800)
x2 = np.linspace(0.01,3, 400)  # Starting from 0.01 to avoid log(0)
# Compute the corresponding y values for each function
f_x = x1**3
g_x = np.exp(x1)
h_x = np.log(x2)

# Create the plot for all three functions
plt.plot(x1, f_x, label="f(x) = x^3", color='r')  # Red line for x^3
plt.plot(x1, g_x, label="g(x) = e^x", color='g')  # Green line for e^x
plt.plot(x2, h_x, label="h(x) = log(x)", color='b')  # Blue line for log(x)

# Add the 'o' marker at x = 0 for h(x) with white fill and blue edge
plt.scatter(0, np.log(0.01), color='white', edgecolors='blue', s=50, zorder=5, linewidths=1)

# Add labels and a title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Multiple Functions: $f(x) = x^3$, $g(x) = e^x$, $h(x) = log(x)$')

plt.xlim([-3, 3])
plt.ylim([-15, 15])

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### 4. Styling Lines
# - Create a plot with the following functions, each with a different color and line style:
#   - $f(x) = x^2$
#   - $g(x) = x^3$
#   - $h(x) = x^4$
#   - $i(x) = x^5$
# - Demonstrate at least 4 different color specification methods

# %%
# Generate values for x
x = np.linspace(-2, 2, 400)

# Compute the corresponding y values for each function
f_x = x**2
g_x = x**3
h_x = x**4
i_x = x**5

# Create the plot with different line styles and color specifications
plt.plot(x, f_x, label="$f(x) = x^2$", color='red', linestyle='-', linewidth=2)   # Color name
plt.plot(x, g_x, label="$g(x) = x^3$", color='#1f77b4', linestyle='--', linewidth=2)  # Hex color code
plt.plot(x, h_x, label="$h(x) = x^4$", color=(0.2, 0.6, 0.2), linestyle=':', linewidth=2)  # RGB tuple
plt.plot(x, i_x, label="$i(x) = x^5$", color='0.5', linestyle='-.', linewidth=2)  # Grayscale value

# Add labels and a title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Styling Lines with Different Colors and Line Styles')

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### 5. Axes Limits and Scaling
# - Plot the function $f(x) = \frac{1}{x^2 + 1}$ over the range $[-10, 10]$
# - Set appropriate custom x and y limits to showcase the function's behavior
# - Create another plot of the same function with reversed x and y axes
# - Demonstrate the use of `plt.axis('tight')` and `plt.axis('equal')`

# %%
# Generate values for x in the range [-10, 10]
x = np.linspace(-10, 10, 400)

# Compute the corresponding y values for f(x) = 1 / (x^2 + 1)
y = 1 / (x**2 + 1)

# 1. Plot with custom x and y limits
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$f(x) = \\frac{1}{x^2 + 1}$")
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of $f(x) = \\frac{1}{x^2 + 1}$')

# Set custom limits for x and y
plt.xlim(-10, 10)
plt.ylim(0, 1)

# Add a legend
plt.legend()

# Display the plot
plt.show()

# 2. Reversed Axes Plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$f(x) = \\frac{1}{x^2 + 1}$")
plt.xlabel('y')
plt.ylabel('f(y)')
plt.title('Reversed Axes Plot')

# Reverse the axes
plt.gca().invert_xaxis()  # Reverse x-axis
plt.gca().invert_yaxis()  # Reverse y-axis

# Add a legend
plt.legend()

# Display the plot
plt.show()

# 3. Demonstrating `plt.axis('tight')`
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$f(x) = \\frac{1}{x^2 + 1}$")
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot with `axis(\'tight\')`')

# Use `plt.axis('tight')` to automatically adjust the axes to fit the data
plt.axis('tight')

# Add a legend
plt.legend()

# Display the plot
plt.show()

# 4. Demonstrating `plt.axis('equal')`
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$f(x) = \\frac{1}{x^2 + 1}$")
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot with `axis(\'equal\')`')

# Use `plt.axis('equal')` to make the scales of both axes equal
plt.axis('equal')

# Add a legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### 6. Labels and Legends
# - Create a plot of $f(x) = \sqrt{x}$ and $g(x) = x^{\frac{1}{3}}$ for $x \geq 0$
# - Add a proper title, x-label, y-label, and legend

# %%
# Generate values for x in the range [0, 10]
x = np.linspace(0, 10, 400)

# Compute the corresponding y values for f(x) = sqrt(x) and g(x) = x^(1/3)
f_x = np.sqrt(x)
g_x = x**(1/3)

# Create the plot
plt.figure(figsize=(8, 6))

# Plot f(x) = sqrt(x)
plt.plot(x, f_x, label="$f(x) = \sqrt{x}$", color='blue', linewidth=2)

# Plot g(x) = x^(1/3)
plt.plot(x, g_x, label="$g(x) = x^{1/3}$", color='green', linewidth=2)

# Add title, labels, and legend
plt.title('Plot of $f(x) = \\sqrt{x}$ and $g(x) = x^{1/3}$', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### 7. Basic Scatter Plot
# - Generate 50 random points using `np.random.rand()` for both x and y
# - Create a scatter plot of these points using `plt.plot()` with the 'o' marker
# - Create the same scatter plot using `plt.scatter()`

# %%
# Generate 50 random points for x and y using np.random.rand()
x = np.random.rand(50)
y = np.random.rand(50)

# Create the first scatter plot using plt.plot() with 'o' marker
plt.figure(figsize=(8, 6))
plt.plot(x, y, 'o', label='Scatter plot using plt.plot()', color='blue')
plt.title('Basic Scatter Plot (using plt.plot())')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Create the second scatter plot using plt.scatter()
plt.figure(figsize=(8, 6))
plt.scatter(x, y, label='Scatter plot using plt.scatter()', color='red')
plt.title('Basic Scatter Plot (using plt.scatter())')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ### 8. Customizing Scatter Plots
# - Generate data for the function $f(x) = x \sin(x)$ over the range $[0, 4\pi]$
# - Create a scatter plot of this data with a line connecting the points
# - Customize the plot by changing the marker size, line width, marker face color, marker edge color, and marker edge width

# %%
# Generate values for x in the range [0, 4π]
x = np.linspace(0, 4 * np.pi, 100)
y = x * np.sin(x)  # f(x) = x * sin(x)

# Create a plot with customized markers and a line connecting the points
plt.figure(figsize=(8, 6))

# Plot the scatter plot with 'o' marker, green edge color, and black line
plt.plot(x, y, 'o-',
         label='$f(x) = x \sin(x)$',
         color='black',
         markersize=10,  # marker size
         markeredgecolor='green',  # marker edge color set to green
         markeredgewidth=2,  # marker edge width
         markerfacecolor='yellow',  # marker face color set to yellow
         linewidth=2)  # line width set to 2 (black color will be overridden by 'color')
#cf
# Add a line connecting the points
#plt.plot(x, y, color='black', linewidth=2)  # line connecting the points

# Customize the plot with title, labels, and legend
plt.title('Customized Scatter Plot of $f(x) = x \sin(x)$', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('f(x)', fontsize=12)
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### 9. Combined Plot
# - Plot the function $f(x) = x \cos(x)$ over the range $[-2\pi, 2\pi]$
# - Add scatter points for x values at every $\frac{\pi}{4}$ interval
# - Use different colors and styles for the line and scatter components

# %%
# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='purple', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style
plt.scatter(x_scatter, y_scatter, color='pink', label='Scatter points',
            marker='o', s=100, edgecolor='red', linewidth=2)

# Customize the plot with title, labels, and legend
plt.title('Combined Plot of $f(x) = x \cos(x)$ and Scatter Points', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('f(x)', fontsize=12)
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### 10. Custom Plot with Alternative Style
# - Choose two or more functions from the following list:
#   - $f(x) = \tan(x)$
#   - $g(x) = x e^{-x^2}$
#   - $h(x) = \frac{\sin(x)}{x}$  (with appropriate handling for $x=0$)
#   - $i(x) = \arctan(x)$
#   - $j(x) = \frac{1}{1 + e^{-x}}$  (logistic function)
# - Create a custom plot that combines at least 4 concepts learned (e.g., multiple functions, scatter points, custom colors, line styles, limits, labels, and legend)
# - Use the alternative style you chose in Task 1 for this plot
# - Add comments explaining your choices, the significance of the functions you chose, and how the alternative style affects the plot's appearance

# %%
plt.style.use('seaborn-v0_8-darkgrid')

# %%
# If I don't use h(x)=sin(x)/x, the code is not difficult.
# Python ignore x=0 and generate the graph of h(x) = sin (x)/x, but this is not right.

# Define x values (in the range from -4 to 4, excluding the region near zero for tan(x) to avoid discontinuity)
x = np.linspace(-10, 10, 400)

# Define the functions
f_x = np.tan(x)
g_x = x * np.exp(-x**2)
h_x = np.sin(x) / x  # sin(x)/x →need to exclude 0
j_x = 1 / (1 + np.exp(-x))
i_x = np.arctan(x)

# Scatter points for selected x values
x_scatter = np.arange(-10, 10, 1)
y_scatter_f = np.tan(x_scatter)
y_scatter_g = x_scatter * np.exp(-x_scatter**2)
y_scatter_h = np.sin(x_scatter) / x_scatter # sin(x)/x →need to exclude 0
y_scatter_j = 1 / (1 + np.exp(-x_scatter))
y_scatter_i = np.arctan(x_scatter)

# Create the figure with specific size
plt.figure(figsize=(10, 10))

# 1st plot: tan(x)
plt.subplot(3, 2, 1)
plt.plot(x, f_x, label='$f(x) = \\tan(x)$', color='blue', linestyle='-', linewidth=2)
plt.scatter(x_scatter, y_scatter_f, color='blue', marker='o', s=25,  label='Scatter f(x)')
plt.title('$f(x) = \\tan(x)$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# 2nd plot: x * e^(-x^2)
plt.subplot(3, 2, 2)
plt.plot(x, g_x, label='$g(x) = x e^{-x^2}$', color='red', linestyle='--', linewidth=2)
plt.scatter(x_scatter, y_scatter_g, color='red', marker='s', s=25, label='Scatter g(x)')
plt.title('$g(x) = x e^{-x^2}$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# 3rd plot: sin(x)/x
plt.subplot(3, 2, 3)
plt.plot(x, h_x, label='$h(x) = \\frac{\\sin(x)}{x}$', color='green', linestyle='-.', linewidth=2)
plt.scatter(x_scatter, y_scatter_h, color='green', marker='^', s=25, label='Scatter h(x)')
plt.scatter(0.01, np.sin(0.01)/0.01, color='white', edgecolors='green', s=25, zorder=5, linewidths=2) # Add the 'o' marker at x = 0 for h(x) with white fill and green edge
plt.title('$h(x) = \\frac{\\sin(x)}{x}$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# 4th plot: logistic function
plt.subplot(3, 2, 4)
plt.plot(x, j_x, label='$j(x) = \\frac{1}{1 + e^{-x}}$', color='purple', linestyle=':', linewidth=2)
plt.scatter(x_scatter, y_scatter_j, color='purple', marker='D', s=25, label='Scatter j(x)')
plt.title('$j(x) = \\frac{1}{1 + e^{-x}}$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# 5th plot: arctan(x)
plt.subplot(3, 2, 5)
plt.plot(x, i_x, label='$i(x) = \\arctan(x)$', color='orange', linestyle='-', linewidth=2)
plt.scatter(x_scatter, y_scatter_i, color='orange', marker='x', s=25, label='Scatter i(x)')
plt.title('$i(x) = \\arctan(x)$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-23-c2f8c93519d3>:18: RuntimeWarning: invalid value encountered in divide
#   y_scatter_h = np.sin(x_scatter) / x_scatter # sin(x)/x →need to exclude 0

# %%
# Define x values (in the range from -4 to 4, excluding the region near zero for tan(x) to avoid discontinuity)
x = np.linspace(-10, 10, 400)

# Define the functions
f_x = np.tan(x)
g_x = x * np.exp(-x**2)
h_x = np.sin(x) / x  # sin(x)/x →need to exclude 0
j_x = 1 / (1 + np.exp(-x))
i_x = np.arctan(x)

# Scatter points for selected x values
x_scatter = np.arange(-10,10,1)
y_scatter_f = np.tan(x_scatter)
y_scatter_g = x_scatter * np.exp(-x_scatter**2)
y_scatter_h = np.sin(x_scatter) / x_scatter  # sin(x)/x →need to exclude 0
y_scatter_j = 1 / (1 + np.exp(-x_scatter))
y_scatter_i = np.arctan(x_scatter)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot the functions with different colors and styles
plt.plot(x, f_x, label='$f(x) = \\tan(x)$', color='blue', linestyle='-', linewidth=2)
plt.plot(x, g_x, label='$g(x) = x e^{-x^2}$', color='red', linestyle='--', linewidth=2)
plt.plot(x, h_x, label='$h(x) = \\frac{\\sin(x)}{x}$', color='green', linestyle='-.', linewidth=2) # sin(x)/x →need to exclude 0
plt.plot(x, j_x, label='$j(x) = \\frac{1}{1 + e^{-x}}$', color='purple', linestyle=':', linewidth=2)
plt.plot(x, i_x, label='$i(x) = \\arctan(x)$', color='orange', linestyle='-', linewidth=2)

# Scatter plot points for selected x values
plt.scatter(x_scatter, y_scatter_f, color='blue', marker='o', s=50, label='Scatter f(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_g, color='red', marker='s', s=50, label='Scatter g(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_h, color='green', marker='^', s=50, label='Scatter h(x)', zorder=5)
plt.scatter(0.01, np.sin(0.01)/0.01, color='white', edgecolors='green', s=50, zorder=5, linewidths=2) # Add the 'o' marker at x = 0 for h(x) with white fill and green edge
plt.scatter(x_scatter, y_scatter_j, color='purple', marker='D', s=50, label='Scatter j(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_i, color='orange', marker='x', s=50, label='Scatter i(x)', zorder=5)

# Customize plot limits
plt.xlim([-10, 10])
plt.ylim([-2, 2])

# Add labels and title
plt.title('Custom Plot with Multiple Functions', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)

# Add legend outside the plot area
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()
# Out:
# <ipython-input-24-bd4f586c4a3b>:15: RuntimeWarning: invalid value encountered in divide
#   y_scatter_h = np.sin(x_scatter) / x_scatter  # sin(x)/x →need to exclude 0

# %%
# Define x values (in the range from -4 to 4, excluding the region near zero for tan(x) to avoid discontinuity)
x = np.linspace(-10, 10, 400)

# Define the functions
f_x = np.tan(x)
g_x = x * np.exp(-x**2)
h_x = np.sin(x) / x  # sin(x)/x →need to exclude 0
j_x = 1 / (1 + np.exp(-x))
i_x = np.arctan(x)

# Scatter points for selected x values
x_scatter = np.arange(-10,10,1)
y_scatter_f = np.tan(x_scatter)
#y_scatter_g = x_scatter * np.exp(-x_scatter**2)
#y_scatter_h = np.sin(x_scatter) / x_scatter  # sin(x)/x →need to exclude 0
#y_scatter_j = 1 / (1 + np.exp(-x_scatter))
y_scatter_i = np.arctan(x_scatter)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot the functions with different colors and styles
plt.plot(x, f_x, label='$f(x) = \\tan(x)$', color='blue', linestyle='-', linewidth=2)
#plt.plot(x, g_x, label='$g(x) = x e^{-x^2}$', color='red', linestyle='--', linewidth=2)
#plt.plot(x, h_x, label='$h(x) = \\frac{\\sin(x)}{x}$', color='green', linestyle='-.', linewidth=2) # sin(x)/x →need to exclude 0
#plt.plot(x, j_x, label='$j(x) = \\frac{1}{1 + e^{-x}}$', color='purple', linestyle=':', linewidth=2)
plt.plot(x, i_x, label='$i(x) = \\arctan(x)$', color='orange', linestyle='-', linewidth=2)

# Scatter plot points for selected x values
plt.scatter(x_scatter, y_scatter_f, color='blue', marker='o', s=50, label='Scatter f(x)', zorder=5)
#plt.scatter(x_scatter, y_scatter_g, color='red', marker='s', s=50, label='Scatter g(x)', zorder=5)
#plt.scatter(x_scatter, y_scatter_h, color='green', marker='^', s=50, label='Scatter h(x)', zorder=5)
#plt.scatter(0.01, np.sin(0.01)/0.01, color='white', edgecolors='green', s=50, zorder=5, linewidths=2) # Add the 'o' marker at x = 0 for h(x) with white fill and green edge
#plt.scatter(x_scatter, y_scatter_j, color='purple', marker='D', s=50, label='Scatter j(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_i, color='orange', marker='x', s=50, label='Scatter i(x)', zorder=5)

# Customize plot limits
plt.xlim([-10, 10])
#plt.ylim([-2, 2])
plt.ylim([-4, 4])

# Add labels and title
plt.title('$f(x) = \\tan(x)$ vs $i(x) = \\arctan(x)$', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)

# Add legend outside the plot area
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %% [markdown]
# ### 1. Functions Chosen:
# - **𝑓(𝑥) = tan(𝑥)**: A well-known trigonometric function that exhibits periodic behavior with vertical asymptotes at odd multiples of 𝜋/2.
# - **𝑖(𝑥) = arctan(𝑥)**: The inverse of the tangent function, which behaves smoothly and is defined over all real values of 𝑥. It approaches 𝜋/2 as 𝑥 → ∞ and -𝜋/2 as 𝑥 → -∞.
#
# ### 2. Graph Adjustments:
# - For the tangent graph, since it increases without bound vertically, I adjusted the y-limits to properly capture this behavior.
#
# ### 3. Style Choice: seaborn-v0_8-darkgrid:
# - **Why**: This style enhances readability with its dark background and gridlines, offering better contrast for the plotted functions. The gridlines help in visually aligning the function values, making it easier to analyze the plot.
# - **Effect on Appearance**: The dark background makes the colors of the functions stand out more, and the gridlines provide a helpful reference. This is especially useful when working with complex functions like 𝑓(𝑥) = tan(𝑥), which has rapid oscillations.

# %%
#cf
plt.style.use('seaborn-v0_8-whitegrid')

# Define x values (in the range from -4 to 4, excluding the region near zero for tan(x) to avoid discontinuity)
x = np.linspace(-10, 10, 400)

# Define the functions
f_x = np.tan(x)
g_x = x * np.exp(-x**2)
h_x = np.sin(x) / x  # sin(x)/x →need to exclude 0
j_x = 1 / (1 + np.exp(-x))
i_x = np.arctan(x)

# Scatter points for selected x values
x_scatter = np.arange(-10,10,1)
y_scatter_f = np.tan(x_scatter)
#y_scatter_g = x_scatter * np.exp(-x_scatter**2)
#y_scatter_h = np.sin(x_scatter) / x_scatter  # sin(x)/x →need to exclude 0
#y_scatter_j = 1 / (1 + np.exp(-x_scatter))
y_scatter_i = np.arctan(x_scatter)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot the functions with different colors and styles
plt.plot(x, f_x, label='$f(x) = \\tan(x)$', color='blue', linestyle='-', linewidth=2)
#plt.plot(x, g_x, label='$g(x) = x e^{-x^2}$', color='red', linestyle='--', linewidth=2)
#plt.plot(x, h_x, label='$h(x) = \\frac{\\sin(x)}{x}$', color='green', linestyle='-.', linewidth=2) # sin(x)/x →need to exclude 0
#plt.plot(x, j_x, label='$j(x) = \\frac{1}{1 + e^{-x}}$', color='purple', linestyle=':', linewidth=2)
plt.plot(x, i_x, label='$i(x) = \\arctan(x)$', color='orange', linestyle='-', linewidth=2)

# Scatter plot points for selected x values
plt.scatter(x_scatter, y_scatter_f, color='blue', marker='o', s=50, label='Scatter f(x)', zorder=5)
#plt.scatter(x_scatter, y_scatter_g, color='red', marker='s', s=50, label='Scatter g(x)', zorder=5)
#plt.scatter(x_scatter, y_scatter_h, color='green', marker='^', s=50, label='Scatter h(x)', zorder=5)
#plt.scatter(0.01, np.sin(0.01)/0.01, color='white', edgecolors='green', s=50, zorder=5, linewidths=2) # Add the 'o' marker at x = 0 for h(x) with white fill and green edge
#plt.scatter(x_scatter, y_scatter_j, color='purple', marker='D', s=50, label='Scatter j(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_i, color='orange', marker='x', s=50, label='Scatter i(x)', zorder=5)

# Customize plot limits
plt.xlim([-10, 10])
#plt.ylim([-2, 2])
plt.ylim([-4, 4])

# Add labels and title
plt.title('$f(x) = \\tan(x)$ vs $i(x) = \\arctan(x)$', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)

# Add legend outside the plot area
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
plt.style.use('seaborn-v0_8-darkgrid')

#"with appropriate handling for  𝑥=0"

#Challenge h_x = np.sin(x) / x vs j_x = 1 / (1 + np.exp(-x))
#Use 'sinc' function for h(x)

# Define x values (in the range from -10 to 10, excluding the region near zero for tan(x) to avoid discontinuity)
x = np.linspace(-10, 10, 400)
x_sinc = np.linspace(-10, 10, 400)

# Avoid division by zero in h(x) = sin(x)/x at x = 0 by manually setting the value at x=0 to 1
y_sinc = np.sin(x_sinc) / x_sinc
y_sinc[x_sinc == 0] = 1  # Handling the singularity at x=0

# Define the functions
#f_x = np.tan(x)  # tan(x)
g_x = x * np.exp(-x**2)  # x * e^(-x^2)
h_x = np.sin(x_sinc) / x_sinc  # sin(x)/x (sinc function)
#j_x = 1 / (1 + np.exp(-x))  # logistic function
#i_x = np.arctan(x)  # arctan(x)

# Scatter points for selected x values
#x_scatter = np.arange(-10, 10, 1)
#y_scatter_f = np.tan(x_scatter)
y_scatter_g = x_scatter * np.exp(-x_scatter**2)
y_scatter_h = np.sin(x_scatter) / x_scatter
#y_scatter_j = 1 / (1 + np.exp(-x_scatter))
#y_scatter_i = np.arctan(x_scatter)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot the functions with different colors and styles
#plt.plot(x, f_x, label='$f(x) = \\tan(x)$', color='blue', linestyle='-', linewidth=2)
plt.plot(x, g_x, label='$g(x) = x e^{-x^2}$', color='red', linestyle='--', linewidth=2)
plt.plot(x_sinc, h_x, label='$h(x) = \\frac{\\sin(x)}{x}$', color='green', linestyle='-.', linewidth=2)
#plt.plot(x, j_x, label='$j(x) = \\frac{1}{1 + e^{-x}}$', color='purple', linestyle=':', linewidth=2)
#plt.plot(x, i_x, label='$i(x) = \\arctan(x)$', color='orange', linestyle='-', linewidth=2)

# Scatter plot points for selected x values
#plt.scatter(x_scatter, y_scatter_f, color='blue', marker='o', s=50, label='Scatter f(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_g, color='red', marker='s', s=50, label='Scatter g(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_h, color='green', marker='^', s=50, label='Scatter h(x)', zorder=5)
#plt.scatter(x_scatter, y_scatter_j, color='purple', marker='D', s=50, label='Scatter j(x)', zorder=5)
#plt.scatter(x_scatter, y_scatter_i, color='orange', marker='x', s=50, label='Scatter i(x)', zorder=5)

# Customize plot limits
plt.xlim([-10, 10])
plt.ylim([-1.5, 1.5])

# Add labels and title
plt.title('$g(x) = x e^{-x^2}$ vs $h(x) = \\frac{\\sin(x)}{x}$', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)

# Add legend outside the plot area
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()
# Out:
# <ipython-input-27-279580a51e43>:27: RuntimeWarning: invalid value encountered in divide
#   y_scatter_h = np.sin(x_scatter) / x_scatter

# %% [markdown]
# ### 1. Functions Chosen:
# - **$g(x) = x e^{-x^2}$**: This function describes a Gaussian-shaped curve that decreases exponentially as x moves away from zero in both directions. The function approaches zero as \( x \to \infty \) or \( x \to -\infty \).
# - **$h(x) = \frac{\sin(x)}{x}$**: The logistic function is a sigmoidal curve that asymptotically approaches 1 as \( x \to \infty \) and approaches 0 as \( x \to -\infty \). Unlike the exponential decay in g(x), the convergence here is more gradual, resembling a smooth S-shaped curve.
#
# ### 2. Graph Adjustments:
# - The y-limits are adjusted properly.
#
# ### 3. Style Choice: seaborn-v0_8-darkgrid:
# - **Why**: This style improves contrast and makes the graphs more visually appealing, especially when working with complex functions like g(x) and h(x). The dark background and gridlines provide better clarity when examining the functions' behavior.
# - **Effect on Appearance**: The gridlines and dark background make the functions stand out more clearly, helping to distinguish the different regions of the plot. This is particularly useful when comparing functions with different types of convergence behavior, such as the exponential decay in g(x)
#  and the smooth transition in h(x).

# %%
#Challenge h_x = np.sin(x) / x vs j_x = 1 / (1 + np.exp(-x))
#Use 'sinc' function for h(x)

# Define x values (in the range from -10 to 10, excluding the region near zero for tan(x) to avoid discontinuity)
x = np.linspace(-10, 10, 400)
x_sinc = np.linspace(-10, 10, 400)

# Avoid division by zero in h(x) = sin(x)/x at x = 0 by manually setting the value at x=0 to 1
y_sinc = np.sin(x_sinc) / x_sinc
y_sinc[x_sinc == 0] = 1  # Handling the singularity at x=0

# Define the functions
f_x = np.tan(x)  # tan(x)
g_x = x * np.exp(-x**2)  # x * e^(-x^2)
h_x = np.sin(x_sinc) / x_sinc  # sin(x)/x (sinc function)
j_x = 1 / (1 + np.exp(-x))  # logistic function
i_x = np.arctan(x)  # arctan(x)

# Scatter points for selected x values
x_scatter = np.arange(-10, 10, 1)
y_scatter_f = np.tan(x_scatter)
y_scatter_g = x_scatter * np.exp(-x_scatter**2)
y_scatter_h = np.sin(x_scatter) / x_scatter
y_scatter_j = 1 / (1 + np.exp(-x_scatter))
y_scatter_i = np.arctan(x_scatter)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot the functions with different colors and styles
plt.plot(x, f_x, label='$f(x) = \\tan(x)$', color='blue', linestyle='-', linewidth=2)
plt.plot(x, g_x, label='$g(x) = x e^{-x^2}$', color='red', linestyle='--', linewidth=2)
plt.plot(x_sinc, h_x, label='$h(x) = \\frac{\\sin(x)}{x}$', color='green', linestyle='-.', linewidth=2)
plt.plot(x, j_x, label='$j(x) = \\frac{1}{1 + e^{-x}}$', color='purple', linestyle=':', linewidth=2)
plt.plot(x, i_x, label='$i(x) = \\arctan(x)$', color='orange', linestyle='-', linewidth=2)

# Scatter plot points for selected x values
plt.scatter(x_scatter, y_scatter_f, color='blue', marker='o', s=50, label='Scatter f(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_g, color='red', marker='s', s=50, label='Scatter g(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_h, color='green', marker='^', s=50, label='Scatter h(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_j, color='purple', marker='D', s=50, label='Scatter j(x)', zorder=5)
plt.scatter(x_scatter, y_scatter_i, color='orange', marker='x', s=50, label='Scatter i(x)', zorder=5)

# Customize plot limits
plt.xlim([-10, 10])
plt.ylim([-2, 2])

# Add labels and title
plt.title('Custom Plot with Multiple Functions', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)

# Add legend outside the plot area
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()
# Out:
# <ipython-input-28-c3ff75beb7aa>:23: RuntimeWarning: invalid value encountered in divide
#   y_scatter_h = np.sin(x_scatter) / x_scatter

# %% [markdown]
# #### Regarding "with appropriate handling for  𝑥=0"
# ### Return the Normalized Sinc Function
#
# The sinc function is equal to:
#
# $$
# \text{sinc}(x) = \frac{\sin(\pi x)}{\pi x}
# $$
#
# for any argument \(x \neq 0\). sinc(0) takes the limit value 1, making sinc not only everywhere continuous but also infinitely differentiable.
#
# #### Parameters:
# - **x**: `ndarray`
#   - Array (possibly multi-dimensional) of values for which to calculate sinc(x).
#
# #### Returns:
# - **out**: `ndarray`
#   - sinc(x), which has the same shape as the input.

# %%
#Challenge h_x = np.sin(x) / x vs j_x = 1 / (1 + np.exp(-x))
#Use 'sinc' function for h(x)

#Create x_sinc and y_sin, then add y_sinc[x_sinc == 0] = 1 ???

# Define x values (in the range from -4 to 4, excluding the region near zero for tan(x) to avoid discontinuity)
x = np.linspace(-10, 10, 400)
x_sinc = np.linspace(-10, 10, 400)

# Avoid division by zero in h(x) = sin(x)/x at x = 0 by manually setting the value at x=0 to 1
y_sinc = np.sin(x_sinc) / x_sinc
y_sinc[x_sinc == 0] = 1  # Handling the singularity at x=0

# Define the functions
h_x = np.sin(x_sinc) / x_sinc  # sin(x)/x (sinc function)

# Scatter points for selected x values
x_scatter = np.arange(-10,10,1)
y_scatter_h = np.sin(x_scatter) / x_scatter

# Create the figure with specific size
plt.figure(figsize=(10, 10))

# 3rd plot: sin(x)/x (sinc function)
plt.plot(x_sinc, h_x, label='$h(x) = \\frac{\\sin(x)}{x}$', color='green', linestyle='-.', linewidth=2)
plt.scatter(x_scatter, y_scatter_h, color='green', marker='^', s=100, label='Scatter h(x)')
plt.title('$h(x) = \\frac{\\sin(x)}{x}$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend()
# Out:
# <ipython-input-19-5bccbba51be2>:19: RuntimeWarning: invalid value encountered in divide
#   y_scatter_h = np.sin(x_scatter) / x_scatter

# %%
#Challenge h_x = np.sin(x) / x vs j_x = 1 / (1 + np.exp(-x))
#Use 'sinc' function for h(x)

plt.style.use('seaborn-v0_8-darkgrid')

# Define x values (in the range from -4 to 4, excluding the region near zero for tan(x) to avoid discontinuity)
x = np.linspace(-10, 10, 400)
x_sinc = np.linspace(-10, 10, 400)

# Avoid division by zero in h(x) = sin(x)/x at x = 0 by manually setting the value at x=0 to 1
y_sinc = np.sin(x_sinc) / x_sinc
y_sinc[x_sinc == 0] = 1  # Handling the singularity at x=0

# Define the functions
f_x = np.tan(x)
g_x = x * np.exp(-x**2)
h_x = np.sin(x_sinc) / x_sinc  # sin(x)/x (sinc function)
j_x = 1 / (1 + np.exp(-x))
i_x = np.arctan(x)

# Scatter points for selected x values
x_scatter = np.arange(-10,10,1)
y_scatter_f = np.tan(x_scatter)
y_scatter_g = x_scatter * np.exp(-x_scatter**2)
y_scatter_h = np.sin(x_scatter) / x_scatter
y_scatter_j = 1 / (1 + np.exp(-x_scatter))
y_scatter_i = np.arctan(x_scatter)

# Create the figure with specific size
plt.figure(figsize=(10, 10))

# 1st plot: tan(x)
plt.subplot(3, 2, 1)
plt.plot(x, f_x, label='$f(x) = \\tan(x)$', color='blue', linestyle='-', linewidth=2)
plt.scatter(x_scatter, y_scatter_f, color='blue', marker='o', s=50, label='Scatter f(x)')
plt.title('$f(x) = \\tan(x)$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# 2nd plot: x * e^(-x^2)
plt.subplot(3, 2, 2)
plt.plot(x, g_x, label='$g(x) = x e^{-x^2}$', color='red', linestyle='--', linewidth=2)
plt.scatter(x_scatter, y_scatter_g, color='red', marker='s', s=25, label='Scatter g(x)')
plt.title('$g(x) = x e^{-x^2}$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# 3rd plot: sin(x)/x (sinc function)
plt.subplot(3, 2, 3)
plt.plot(x_sinc, h_x, label='$h(x) = \\frac{\\sin(x)}{x}$', color='green', linestyle='-.', linewidth=2)
plt.scatter(x_scatter, y_scatter_h, color='green', marker='^', s=25, label='Scatter h(x)')
plt.title('$h(x) = \\frac{\\sin(x)}{x}$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# 4th plot: logistic function
plt.subplot(3, 2, 4)
plt.plot(x, j_x, label='$j(x) = \\frac{1}{1 + e^{-x}}$', color='purple', linestyle=':', linewidth=2)
plt.scatter(x_scatter, y_scatter_j, color='purple', marker='D', s=25, label='Scatter j(x)')
plt.title('$j(x) = \\frac{1}{1 + e^{-x}}$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# 5th plot: arctan(x)
plt.subplot(3, 2, 5)
plt.plot(x, i_x, label='$i(x) = \\arctan(x)$', color='orange', linestyle='-', linewidth=2)
plt.scatter(x_scatter, y_scatter_i, color='orange', marker='x', s=25, label='Scatter i(x)')
plt.title('$i(x) = \\arctan(x)$', fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10, 10])
plt.ylim([-2, 2])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Add labels and title
plt.title('Custom Plot with Multiple Functions', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)

# Add legend outside the plot area
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-29-e2612d5444fb>:25: RuntimeWarning: invalid value encountered in divide
#   y_scatter_h = np.sin(x_scatter) / x_scatter

# %% [markdown]
# ## 11. Style Comparison
# - Choose one of your previous plots (Tasks 2-9)
# - Recreate it using three different styles: the default style, 'seaborn-whitegrid', and your chosen alternative style
# - Compare and contrast the appearances, discussing which style might be most appropriate for the specific data being plotted

# %%
plt.style.use('default')
#plt.style.use('seaborn-v0_8-whitegrid')
#plt.style.use('seaborn-v0_8-darkgrid')

# ggplot blue #1f77b4
# ggplot orange #ff7f0e

# %%
# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
peak_1_x = -np.pi  # Peak 1 at x = -π
peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

# Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using black)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='black', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using gray and 50% transparency)
# Set edgecolor to be black and fill color to light gray
plt.scatter(x_scatter, y_scatter, color='lightgray', label='Scatter points', marker='o', s=100, edgecolor='black', linewidth=2, alpha=0.5)

# Highlight Peak 1, Peak 2, and the last point in dark gray (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='black', s=100, label='Peak 1', edgecolor='black', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='black', s=100, label='Peak 2', edgecolor='black', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(last_x, last_y, color='black', s=100, label='Last Point', edgecolor='black', linewidth=2, alpha=1.0, zorder=5)

# Add the numeric values next to the peaks (black text)
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='black', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('Number of COVID-19 Infections', fontsize=14, color='black')
plt.xlabel('x', fontsize=12, color='black')
plt.ylabel('f(x)', fontsize=12, color='black')
#plt.legend()

# Add grid (using the same style as the original, light gray grid)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16']  # Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12']  # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='black')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='black')  # Replace 'f(x)' with 'Number of Infections'

# Display the plot
plt.show()

# %%
# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
peak_1_x = -np.pi  # Peak 1 at x = -π
peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

# Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using black)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='black', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using gray and 50% transparency)
# Set edgecolor to be black and fill color to light gray
plt.scatter(x_scatter, y_scatter, color='lightgray', label='Scatter points', marker='o', s=100, edgecolor='darkgray', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in dark gray (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='black', s=100, label='Peak 1', edgecolor='black', linewidth=2, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='black', s=100, label='Peak 2', edgecolor='black', linewidth=2, zorder=5)
plt.scatter(last_x, last_y, color='black', s=100, label='Last Point', edgecolor='black', linewidth=2, zorder=5)

# Add the numeric values next to the peaks (black text)
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='black', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('Number of COVID-19 Infections', fontsize=14, color='white')
plt.xlabel('x', fontsize=12, color='white')
plt.ylabel('f(x)', fontsize=12, color='white')
#plt.legend()

# Add grid (using the same style as the original, light gray grid)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16'], color = 'white'  # Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12'], color = 'white'  # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='white')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='white')  # Replace 'f(x)' with 'Number of Infections'

# Set the figure background color to dark grey (blackish)
plt.gcf().set_facecolor('#2F2F2F')  # Dark background for the figure

# Set the axes background color to white
plt.gca().set_facecolor('white')  # White background for the plot itself
# Display the plot

plt.show()

# %%
#1 plt.style.use('default') light backglound
plt.style.use('default')

# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
peak_1_x = -np.pi  # Peak 1 at x = -π
peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

# Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('Number of COVID-19 Infections', fontsize=14, color='black')
plt.xlabel('x', fontsize=12, color='black')
plt.ylabel('f(x)', fontsize=12, color='black')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16']  # Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12']  # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='black')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='black')  # Replace 'f(x)' with 'Number of Infections'

# Display the plot
plt.show()

# %%
#2 plt.style.use('default') dark back glound
plt.style.use('default')

# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
peak_1_x = -np.pi  # Peak 1 at x = -π
peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

# Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('Number of COVID-19 Infections', fontsize=14, color='white')
plt.xlabel('x', fontsize=12, color='white')
plt.ylabel('f(x)', fontsize=12, color='white')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16'],
    color='white'# Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12'],
    color='white' # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='white')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='white')  # Replace 'f(x)' with 'Number of Infections'

# Set the figure background color to dark grey (blackish)
plt.gcf().set_facecolor('#2F2F2F')  # Dark background for the figure

# Set the axes background color to white
plt.gca().set_facecolor('white')  # White background for the plot itself

# Display the plot
plt.show()

# %%
#plt.style.use('default')
plt.style.use('seaborn-v0_8-whitegrid')
#plt.style.use('seaborn-v0_8-darkgrid')

# ggplot blue #1f77b4
# ggplot orange #ff7f0e

# %%
#3 'seaborn-v0_8-whitegrid' light background
plt.style.use('seaborn-v0_8-whitegrid')

# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
peak_1_x = -np.pi  # Peak 1 at x = -π
peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

# Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('Number of COVID-19 Infections', fontsize=14, color='black')
plt.xlabel('x', fontsize=12, color='black')
plt.ylabel('f(x)', fontsize=12, color='black')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16']  # Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12']  # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='black')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='black')  # Replace 'f(x)' with 'Number of Infections'

# Display the plot
plt.show()

# %%
#4 'seaborn-v0_8-whitegrid' dark background
plt.style.use('seaborn-v0_8-whitegrid')

# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
peak_1_x = -np.pi  # Peak 1 at x = -π
peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

# Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('Number of COVID-19 Infections', fontsize=14, color='white')
plt.xlabel('x', fontsize=12, color='white')
plt.ylabel('f(x)', fontsize=12, color='white')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16'],
    color='white'# Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12'],
    color='white' # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='white')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='white')  # Replace 'f(x)' with 'Number of Infections'

# Set the figure background color to dark grey (blackish)
plt.gcf().set_facecolor('#2F2F2F')  # Dark background for the figure

# Set the axes background color to white
plt.gca().set_facecolor('white')  # White background for the plot itself

# Display the plot
plt.show()

# %%
#plt.style.use('default')
#plt.style.use('seaborn-v0_8-whitegrid')
plt.style.use('seaborn-v0_8-darkgrid')

# ggplot blue #1f77b4
# ggplot orange #ff7f0e

# %%
#5 'seaborn-v0_8-darkgrid' light background
plt.style.use('seaborn-v0_8-darkgrid')

# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
peak_1_x = -np.pi  # Peak 1 at x = -π
peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

# Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('Number of COVID-19 Infections', fontsize=14, color='black')
plt.xlabel('x', fontsize=12, color='black')
plt.ylabel('f(x)', fontsize=12, color='black')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16']  # Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12']  # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='black')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='black')  # Replace 'f(x)' with 'Number of Infections'

# Display the plot
plt.show()

# %%
#6 'seaborn-v0_8-darkgrid' dark background
plt.style.use('seaborn-v0_8-darkgrid')

#In seaborn-v0_8-darkgrid, when the surrounding frame of the graph is darkened,
#the background's grayish-purple automatically disappears,
#so I added the background color #f0f0f8 for demonstration purposes.

# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
peak_1_x = -np.pi  # Peak 1 at x = -π
peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

# Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('Number of COVID-19 Infections', fontsize=14, color='white')
plt.xlabel('x', fontsize=12, color='white')
plt.ylabel('f(x)', fontsize=12, color='white')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16'],
    color='white'# Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12'],
    color='white' # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='white')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='white')  # Replace 'f(x)' with 'Number of Infections'

# Set the figure background color to dark grey (blackish)
plt.gcf().set_facecolor('#2F2F2F')  # Dark background for the figure

# Set the axes background color to white
plt.gca().set_facecolor('#f0f0f8')  # White background for the plot itself

# Display the plot
plt.show()

# %%
#####1 plt.style.use('default') light backglound
plt.style.use('default')

# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
peak_1_x = -np.pi  # Peak 1 at x = -π
peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

###
# Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('- A1 Default - \n Number of COVID-19 Infections', fontsize=14, color='black')
plt.xlabel('x', fontsize=12, color='black')
plt.ylabel('f(x)', fontsize=12, color='black')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16']  # Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12']  # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='black')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='black')  # Replace 'f(x)' with 'Number of Infections'

# Display the plot
plt.show()


#####3 'seaborn-v0_8-whitegrid' light background
plt.style.use('seaborn-v0_8-whitegrid')

# Generate x values over the range [-2π, 2π]
#x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
#y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
#x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
#y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
#peak_1_x = -np.pi  # Peak 1 at x = -π
#peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
#last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
#peak_1_y = peak_1_x * np.cos(peak_1_x)
#peak_2_y = peak_2_x * np.cos(peak_2_x)
#last_y = last_x * np.cos(last_x)

### Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('- A2 Seaborn Whitegrid - \n Number of COVID-19 Infections', fontsize=14, color='black')
plt.xlabel('x', fontsize=12, color='black')
plt.ylabel('f(x)', fontsize=12, color='black')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16']  # Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12']  # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='black')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='black')  # Replace 'f(x)' with 'Number of Infections'

# Display the plot
plt.show()


#####5 'seaborn-v0_8-darkgrid' light background
plt.style.use('seaborn-v0_8-darkgrid')

# Generate x values over the range [-2π, 2π]
#x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
#y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
#x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
#y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
#peak_1_x = -np.pi  # Peak 1 at x = -π
#peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
#last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
#peak_1_y = peak_1_x * np.cos(peak_1_x)
#peak_2_y = peak_2_x * np.cos(peak_2_x)
#last_y = last_x * np.cos(last_x)

### Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, alpha=1.0, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('- A3 Seaborn Darkgrid - \n Number of COVID-19 Infections', fontsize=14, color='black')
plt.xlabel('x', fontsize=12, color='black')
plt.ylabel('f(x)', fontsize=12, color='black')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16']  # Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12']  # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='black')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='black')  # Replace 'f(x)' with 'Number of Infections'

# Display the plot
plt.show()

# %%
#####2 plt.style.use('default') dark back glound
plt.style.use('default')

# Generate x values over the range [-2π, 2π]
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
peak_1_x = -np.pi  # Peak 1 at x = -π
peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

### Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('Number of COVID-19 Infections', fontsize=14, color='white')
plt.xlabel('x', fontsize=12, color='white')
plt.ylabel('f(x)', fontsize=12, color='white')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16'],
    color='white'# Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12'],
    color='white' # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='white')  # Replace 'x' with 'Months'
plt.ylabel('- B1 Default in a Dark Room -Number of Infections (M people)', fontsize=12, color='white')  # Replace 'f(x)' with 'Number of Infections'

# Set the figure background color to dark grey (blackish)
plt.gcf().set_facecolor('#2F2F2F')  # Dark background for the figure

# Set the axes background color to white
plt.gca().set_facecolor('white')  # White background for the plot itself

# Display the plot
plt.show()


#####4 'seaborn-v0_8-whitegrid' dark background
plt.style.use('seaborn-v0_8-whitegrid')

# Generate x values over the range [-2π, 2π]
#x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
#y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
#x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
#y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
#peak_1_x = -np.pi  # Peak 1 at x = -π
#peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
#last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
peak_1_y = peak_1_x * np.cos(peak_1_x)
peak_2_y = peak_2_x * np.cos(peak_2_x)
last_y = last_x * np.cos(last_x)

### Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('- B2 Seaborn Whitegrid in a Dark Room - \n Number of COVID-19 Infections', fontsize=14, color='white')
plt.xlabel('x', fontsize=12, color='white')
plt.ylabel('f(x)', fontsize=12, color='white')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16'],
    color='white'# Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12'],
    color='white' # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='white')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='white')  # Replace 'f(x)' with 'Number of Infections'

# Set the figure background color to dark grey (blackish)
plt.gcf().set_facecolor('#2F2F2F')  # Dark background for the figure

# Set the axes background color to white
plt.gca().set_facecolor('white')  # White background for the plot itself

# Display the plot
plt.show()



#####6 'seaborn-v0_8-darkgrid' dark background
plt.style.use('seaborn-v0_8-darkgrid')

#In seaborn-v0_8-darkgrid, when the surrounding frame of the graph is darkened,
#the background's grayish-purple automatically disappears,
#so I added the background color #f0f0f8 for demonstration purposes.

# Generate x values over the range [-2π, 2π]
#x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
#y = x * np.cos(x)  # f(x) = x * cos(x)

# Generate scatter points for x values at every π/4 interval
#x_scatter = np.arange(-2 * np.pi, 2 * np.pi, np.pi / 4)
#y_scatter = x_scatter * np.cos(x_scatter)

# Define the positions for the peaks
#peak_1_x = -np.pi  # Peak 1 at x = -π
#peak_2_x = 0.25 * np.pi  # Peak 2 at x = 0.25π
#last_x = 2 * np.pi  # Last point at x = 2π

# Calculate the y-values for the peaks
#peak_1_y = peak_1_x * np.cos(peak_1_x)
#peak_2_y = peak_2_x * np.cos(peak_2_x)
#last_y = last_x * np.cos(last_x)

### Create a plot
plt.figure(figsize=(8, 6))

# Plot the line of f(x) = x * cos(x) with a solid line style (using muted blue)
plt.plot(x, y, label='$f(x) = x \cos(x)$', color='#1f77b4', linewidth=2)

# Plot the scatter points at every π/4 interval with a different marker style (using muted blue and 50% transparency)
# Set edgecolor to be the same blue color with no transparency
plt.scatter(x_scatter, y_scatter, color='#1f77b4', label='Scatter points', marker='o', s=100, edgecolor='#1f77b4', linewidth=2)

# Highlight Peak 1, Peak 2, and the last point in muted orange (with full opacity for the interior)
plt.scatter(peak_1_x, peak_1_y, color='#ff7f0e', s=100, label='Peak 1', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(peak_2_x, peak_2_y, color='#ff7f0e', s=100, label='Peak 2', edgecolor='#ff7f0e', linewidth=2, zorder=5)
plt.scatter(last_x, last_y, color='#ff7f0e', s=100, label='Last Point', edgecolor='#ff7f0e', linewidth=2, zorder=5)

# Add the numeric values next to the peaks
plt.text(peak_1_x, peak_1_y + 0.5, f'Outbreak 1 \n April 2020 \n {peak_1_y + 6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(peak_2_x, peak_2_y + 0.5, f'Outbreak 2 \n September 2020 \n {peak_2_y+6:.2f} M people', color='black', ha='center', fontsize=10)
plt.text(last_x - 3, last_y -1, f'Outbreak 3 New Variant Outbreak) \n April 2021 \n already {last_y+6:.2f} M people', color='red', ha='center', fontsize=10)

# Customize the x-axis ticks to show multiples of pi
plt.xticks([-np.pi, 0, np.pi, 2*np.pi], [r'$-\pi$', r'$0$', r'$\pi$', r'$2\pi$'])

# Customize the plot with title, labels, legend, and grid
plt.title('- B3 Seaborn Darkgrid in a Dark Room - \nNumber of COVID-19 Infections', fontsize=14, color='white')
plt.xlabel('x', fontsize=12, color='white')
plt.ylabel('f(x)', fontsize=12, color='white')
#plt.legend()

# Add grid (using the same style as the original)
plt.grid(True, which='both', linestyle=':', color='lightgray', linewidth=0.5)

# Customize the x-axis ticks to show custom labels for specific multiples of pi
plt.xticks(
    [-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],  # x-values where the ticks will appear
    ['0', '4', '8', '12', '16'],
    color='white'# Custom labels corresponding to the x-values
)

# Customize the y-axis ticks to show desired labels (if needed)
plt.yticks(
    [-6, -4, -2, 0, 2, 4, 6],  # y-values where the ticks will appear
    ['0', '2', '4', '6', '8', '10', '12'],
    color='white' # Custom labels corresponding to the y-values
)

plt.xlabel('Months', fontsize=12, color='white')  # Replace 'x' with 'Months'
plt.ylabel('Number of Infections (M people)', fontsize=12, color='white')  # Replace 'f(x)' with 'Number of Infections'

# Set the figure background color to dark grey (blackish)
plt.gcf().set_facecolor('#2F2F2F')  # Dark background for the figure

# Set the axes background color to white
plt.gca().set_facecolor('#f0f0f8')  # White background for the plot itself

# Display the plot
plt.show()

# %% [markdown]
# **Reflection on Graph in Task 9**
#
# The graph in Task 9 follows a common structure frequently encountered in fields like medicine and economics, presenting actual data trends. In this case, I have assumed the graph represents the progression of COVID-19 infections.
#
# Graphs utilized in academic research and publications, such as those for journal submissions, are often created in large formats like A0. This raises the question of which style—**default**, **seaborn-whitegrid**, or **seaborn-darkgrid**—would be most suitable when preparing for a conference presentation.
#
# 1. **Default Style**
# The default style (A1) offers a clean and minimalistic design, ideal for general-purpose plots where the focus remains on the data itself, free from distractions. This style is excellent for publication-ready graphics. However, for a conference presentation, it has its limitations, as the absence of gridlines can make it harder for the audience to follow the data trends, and the borders can become somewhat distracting, adding unnecessary visual noise.
#
# 2. **Seaborn-Whitegrid Style**
# In contrast, the **seaborn-whitegrid** style (A2) features a clear white background with subtle gridlines, which enhance the readability of the graph without overpowering the data. The gridlines help viewers track the values with ease, making the key trends and peak points stand out more prominently. This style provides an elegant and clear presentation, especially suitable for data-focused conference talks.
#
# 3. **Seaborn-Darkgrid Style**
# The **seaborn-darkgrid** style (A3) uses a soft purple-gray background, which was visually appealing when working on a light computer display. However, when I attempted to simulate the environment of a conference presentation (B3), particularly in dark-lit rooms, the dark background interfered with the graph's readability. The black border, though intended to complement the dark theme, only exacerbated this issue, making the background color more distracting rather than enhancing the overall clarity of the graph.
#
# **Conclusion**
# In conclusion, for conference presentations, especially in dark conference halls, the **seaborn-whitegrid** style proves to be the most effective. It strikes a balance between clarity and aesthetic appeal, ensuring the graph remains easily readable and visually impactful without any unnecessary distractions.
